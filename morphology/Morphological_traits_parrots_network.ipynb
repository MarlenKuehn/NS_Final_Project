# %%
import pandas as pd
import networkx as nx


import matplotlib.pyplot as plt

from tabulate import tabulate
import numpy as np

from sklearn.preprocessing import MinMaxScaler, StandardScaler


from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import cosine_similarity
import csv
import json

# %%
# !pip install xlsxwriter
# !pip install geopandas
# !pip install contextily
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.0
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Collecting contextily
#   Downloading contextily-1.6.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from contextily) (3.8.0)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from contextily) (11.0.0)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from contextily) (1.4.2)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from contextily) (2024.9.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.10/dist-packages (from mercantile->contextily) (8.1.7)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (2024.8.30)
# Collecting cligj>=0.5 (from rasterio->contextily)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->contextily)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (2.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 69.2 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: mercantile, cligj, click-plugins, affine, rasterio, contextily
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 contextily-1.6.2 mercantile-1.2.1 rasterio-1.4.3

# %%
df = pd.read_csv('Psittaciformes.csv',
                 on_bad_lines='skip',
                 encoding='utf-8',
                 dtype=str,  # Read all as string first
                 skip_blank_lines=True,
                 header=0,
                 skipinitialspace=True)

# %%
print(df.columns)
# Out:
# Index(['scientificName', 'kingdomName', 'phylumName', 'className', 'orderName',
#        'familyName', 'genusName', 'speciesName', 'redlistCategory',
#        'redlistCriteria', 'yearPublished', 'assessmentDate', 'criteriaVersion',
#        'language', 'populationTrend', 'systems', 'realm', 'yearLastSeen',
#        'possiblyExtinct', 'possiblyExtinctInTheWild', 'scopes', 'Sequence',
#        'Avibase.ID1', 'Total.individuals', 'Female', 'Male', 'Unknown',
#        'Complete.measures', 'Beak.Length_Culmen', 'Beak.Length_Nares',
#        'Beak.Width', 'Beak.Depth', 'Tarsus.Length', 'Wing.Length',
#        'Kipps.Distance', 'Secondary1', 'Hand-Wing.Index', 'Tail.Length',
#        'Mass', 'Mass.Source', 'Mass.Refs.Other', 'Inference',
#        'Traits.inferred', 'Reference.species', 'Habitat', 'Habitat.Density',
#        'Migration', 'Trophic.Level', 'Trophic.Niche', 'Primary.Lifestyle',
#        'Min.Latitude', 'Max.Latitude', 'Centroid.Latitude',
#        'Centroid.Longitude', 'Range.Size', 'internalTaxonId_x', 'assessmentId',
#        'internalTaxonId_y', 'taxonomicNotes', 'rationale', 'habitat',
#        'threats', 'population', 'range', 'useTrade', 'conservationActions',
#        'authority'],
#       dtype='object')

# %%
basic_columns_list = [
    'scientificName',
    'familyName',
    'orderName',

    'Beak.Length_Culmen',
    'Beak.Length_Nares',
    'Beak.Width',
    'Beak.Depth',
    'Tarsus.Length',
    'Wing.Length',
    'Kipps.Distance',
    'Hand-Wing.Index',
    'Tail.Length',
    'Mass',

    'Habitat',
    'Habitat.Density',
    'Min.Latitude',
    'Max.Latitude',
    'Centroid.Latitude',
    'Centroid.Longitude',
    'Range.Size',


    'redlistCategory',
    'populationTrend',

]

# %%
df = df[basic_columns_list]

# %%
def analyze_habitats(data):
    """
    List and count unique habitat values
    """
    # Get unique habitats and their counts
    habitat_counts = data['Habitat'].value_counts()

    print("Unique Habitats and their counts:\n")
    print("Habitat Type".ljust(50), "Count")
    print("-" * 60)

    for habitat, count in habitat_counts.items():
        print(f"{str(habitat).ljust(50)} {count}")

    print("\nTotal number of unique habitats:", len(habitat_counts))
    print("Total number of records:", len(data))
    print("Number of null/missing values:", data['Habitat'].isna().sum())

# %%
analyze_habitats(df)
# Out:
# Unique Habitats and their counts:
#
# Habitat Type                                       Count
# ------------------------------------------------------------
# Forest                                             318
# Woodland                                           49
# Shrubland                                          22
# Grassland                                          7
# Human Modified                                     2
# Desert                                             1
#
# Total number of unique habitats: 6
# Total number of records: 401
# Number of null/missing values: 2

# %%
def plot_samples_per_latitude(data, n_lat_bins=10):
    """
    Create a histogram showing number of Birds per latitude band
    """
    # Convert latitude to numeric
    lat = pd.to_numeric(data['Centroid.Latitude'], errors='coerce')

    # Remove NaN values
    lat = lat[~np.isnan(lat)]

    # Create figure
    fig, ax = plt.subplots(figsize=(12, 6))

    # Create histogram
    counts, bins, _ = ax.hist(lat, bins=n_lat_bins, color='skyblue',
                             edgecolor='black', alpha=0.7)

    # Add count labels on top of each bar
    for i in range(len(counts)):
        ax.text(bins[i] + (bins[i+1]-bins[i])/2, counts[i],
                f'{int(counts[i])}',
                horizontalalignment='center',
                verticalalignment='bottom')

    # Customize plot
    ax.set_title('Number of Birds per Latitude Band', pad=20)
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Number of Birds')

    # Add grid
    ax.grid(True, alpha=0.2)

    # Add total sample size
    ax.text(0.98, 0.98, f'Total Birds = {len(lat)}',
            transform=ax.transAxes,
            horizontalalignment='right',
            verticalalignment='top',
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

    plt.tight_layout()
    return fig

# %%
# Create the plot
fig = plot_samples_per_latitude(df)
plt.show()

# %%
def plot_samples_per_longitude(data, n_lon_bins=10):
    """
    Create a histogram showing number of Birds per longitude band
    """
    # Convert longitude to numeric
    lon = pd.to_numeric(data['Centroid.Longitude'], errors='coerce')

    # Remove NaN values
    lon = lon[~np.isnan(lon)]

    # Create figure
    fig, ax = plt.subplots(figsize=(12, 6))

    # Create histogram
    counts, bins, _ = ax.hist(lon, bins=n_lon_bins, color='skyblue',
                             edgecolor='black', alpha=0.7)

    # Add count labels on top of each bar
    for i in range(len(counts)):
        ax.text(bins[i] + (bins[i+1]-bins[i])/2, counts[i],
                f'{int(counts[i])}',
                horizontalalignment='center',
                verticalalignment='bottom')

    # Customize plot
    ax.set_title('Number of Birds per Longitude Band', pad=20)
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Number of Birds')

    # Add grid
    ax.grid(True, alpha=0.2)

    # Add total sample size
    ax.text(0.98, 0.98, f'Total Birds = {len(lon)}',
            transform=ax.transAxes,
            horizontalalignment='right',
            verticalalignment='top',
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

    # Add hemisphere lines and labels
    ax.axvline(x=0, color='red', linestyle='--', alpha=0.5)
    ax.text(2, ax.get_ylim()[1], 'Eastern Hemisphere',
            color='red', alpha=0.7, ha='left', va='bottom')
    ax.text(-2, ax.get_ylim()[1], 'Western Hemisphere',
            color='red', alpha=0.7, ha='right', va='bottom')

    plt.tight_layout()
    return fig


fig = plot_samples_per_longitude(df)
plt.show()

# %%
def plot_redlist_distribution(df, figsize=(6, 4), dpi=300):
    """
    Creates a histogram/distribution plot of Red List categories with smaller dimensions
    """
    # Define valid categories and filter
    valid_categories = [
        'Least Concern',
        'Vulnerable',
        'Endangered',
        'Critically Endangered',
        'Extinct in the Wild',
        'Near Threatened',
        'Extinct'
    ]

    df_filtered = df[df['redlistCategory'].isin(valid_categories)]




    # Define IUCN Red List colors
    colors = {
        'Least Concern': '#00FF00',        # Green
        'Vulnerable': '#FFD300',# Yellow
        'Near Threatened': '#CFD300',
        'Endangered': '#FF6B00',           # Orange
        'Critically Endangered': '#D60B0B', # Red
        'Extinct in the Wild': '#2D1F15',  # Dark Brown
        'Extinct': '#000000',              # Black
    }

    # Calculate value counts and percentages
    counts = df_filtered['redlistCategory'].value_counts()
    total_filtered = len(df_filtered)
    total_original = len(df)

    # Create figure with smaller size
    plt.figure(figsize=figsize, dpi=dpi)

    # Create bar plot
    bars = plt.bar(range(len(counts)), counts,
                  color=[colors.get(x, '#808080') for x in counts.index])

    # Customize plot with smaller font sizes
    plt.title('IUCN Red List Categories', pad=10, fontsize=10)
    plt.xlabel('Status', fontsize=8)
    plt.ylabel('Count', fontsize=8)

    # Rotate x-axis labels with smaller font
    plt.xticks(range(len(counts)), counts.index, rotation=45, ha='right', fontsize=6)
    plt.yticks(fontsize=6)

    # Add count labels with smaller font
    for bar in bars:
        height = bar.get_height()
        percentage = (height/total_filtered) * 100
        plt.text(bar.get_x() + bar.get_width()/2., height,
                f'{int(height)}\n({percentage:.1f}%)',
                ha='center', va='bottom', fontsize=6)

    # Add both totals to upper right
    plt.text(0.02, 0.98,
             f'Total (original): {total_original:,}\nTotal (filtered): {total_filtered:,}',
             transform=plt.gca().transAxes,
             bbox=dict(facecolor='white', alpha=0.8),
             verticalalignment='top',
             horizontalalignment='right',
             fontsize=6)

    plt.tight_layout()

    return plt.gcf()

# Usage:
fig = plot_redlist_distribution(df)
plt.show()

# %%
traits = [
    'Beak.Length_Culmen',
    'Beak.Length_Nares',
    'Beak.Width',
    'Beak.Depth',
    'Tarsus.Length',
    'Wing.Length',
    'Kipps.Distance',
    'Hand-Wing.Index',
    'Tail.Length',
    'Mass'
]

# %%
unique_values = df['familyName'].unique()
print(unique_values)
# Out:
# ['PSITTACIDAE' 'CACATUIDAE' 'STRIGOPIDAE']

# %%
def standardize_traits(df_traits, traits):
    """Standardize/Normalize morphological traits."""
    scaler = StandardScaler()
    standardized_traits = scaler.fit_transform(df_traits[traits])
    species_names = df_traits['scientificName'].values
    return standardized_traits, species_names

def compute_similarity(standardized_traits):
    """
    Compute cosine similarity between species and ensure values are in [-1,1] range.

    Parameters:
        standardized_traits: numpy array of standardized morphological traits
    Returns:
        similarity_matrix: numpy array of pairwise similarities
    """
    # Compute cosine similarity
    similarity_matrix = cosine_similarity(standardized_traits)

    # Clip values to ensure they're in [-1,1] range
    similarity_matrix = np.clip(similarity_matrix, -1, 1)

    # Additional checks
    print("Similarity matrix range:",
          f"min: {similarity_matrix.min():.3f}, max: {similarity_matrix.max():.3f}")

    # Verify similarity range
    if not np.all((similarity_matrix >= -1) & (similarity_matrix <= 1)):
        print("Warning: Original similarity values were outside [-1,1] range")

    return similarity_matrix

# %%
def create_knn_network(similarity_matrix, species_names, df_data, k=5):
    """
    Create network with node attributes and k-nearest neighbor connections.
    Prevents self-loops and ensures proper KNN connections.

    Parameters:
        similarity_matrix: Matrix of pairwise species similarities
        species_names: List of species names
        df_data: DataFrame containing species attributes (lat, long, family, etc.)
        k: Number of nearest neighbors to connect for each node
    """
    G_knn = nx.Graph()

    # Add nodes with attributes
    for species in species_names:
        # Get species data from DataFrame
        species_data = df_data[df_data['scientificName'] == species].iloc[0]

        # Add node with attributes
        G_knn.add_node(
            species,
            latitude=species_data['Centroid.Latitude'],
            longitude=species_data['Centroid.Longitude'],
            family=species_data['familyName'],
            scientific_name=species
        )

    # Create a mask for the diagonal to exclude self-connections
    np.fill_diagonal(similarity_matrix, -np.inf)  # Set diagonal to negative infinity

    # Add edges based on k-nearest neighbors
    for i in range(len(species_names)):
        # Get indices of k most similar species (excluding self)
        similarities = similarity_matrix[i]
        # Argsort in descending order (most similar first)
        most_similar_indices = np.argsort(similarities)[::-1][:k]

        # Add edges to k nearest neighbors
        for j in most_similar_indices:
            G_knn.add_edge(
                species_names[i],
                species_names[j],
                weight=similarity_matrix[i][j]
            )

    #Check for self-loops
    self_loops = list(nx.selfloop_edges(G_knn))
    if self_loops:
        print("Warning: Self-loops found in the network:")
        for edge in self_loops:
            print(f"Self-loop found for node: {edge[0]}")
    else:
        print("No self-loops found in the network")

    # Additional network statistics
    print(f"\nNetwork Statistics:")
    print(f"Number of nodes: {G_knn.number_of_nodes()}")
    print(f"Number of edges: {G_knn.number_of_edges()}")
    print(f"Average degree: {sum(dict(G_knn.degree()).values()) / G_knn.number_of_nodes():.2f}")

    return G_knn

# %%
# 1. Data Preparation
# Create a copy of the data with species names and morphological traits
# Drop any rows with missing values (NaN)
df_traits = df[['scientificName'] + traits].copy()
df_traits = df_traits.dropna()

# 2. Data Standardization
# StandardScaler transforms features to have mean=0 and variance=1
# This ensures all traits contribute equally regardless of their original scales
standardized_traits, species_names = standardize_traits(df_traits, traits)

# 3. Similarity Calculation
# Compute cosine similarity between all pairs of species
# Result is a square matrix where each cell[i,j] is similarity between species i and j
similarity_matrix = compute_similarity(standardized_traits)
# Out:
# Similarity matrix range: min: -0.989, max: 1.000

# %%
# Visualize similarity distribution
def plot_similarity_distribution(similarity_matrix):
    """
    Plot the distribution of similarity values to help with thresholding
    """
    plt.figure(figsize=(10, 6))
    # Get upper triangle values
    upper_tri = similarity_matrix[np.triu_indices(len(similarity_matrix), k=1)]

    plt.hist(upper_tri, bins=50)
    plt.title('Distribution of Similarity Values')
    plt.xlabel('Similarity')
    plt.ylabel('count')

# %%
plot_similarity_distribution(similarity_matrix)

# %%
# Save similarity matrix
similarity_df = pd.DataFrame(similarity_matrix,
                           index=species_names,
                           columns=species_names)
similarity_df.to_excel('similarity_matrix.xlsx')

# %%
G_knn = create_knn_network(
        similarity_matrix=similarity_matrix,
        species_names=species_names,
        df_data=df,
        k=5
)
# Out:
# No self-loops found in the network
#
# Network Statistics:
# Number of nodes: 401
# Number of edges: 1405
# Average degree: 7.01

# %%
def save_graph_to_graphml(G, filename, compress=True):
    """
    Save network to GraphML format with proper attribute handling

    Parameters:
    G: NetworkX graph
    filename: Output filename (with or without extension)
    compress: Boolean, whether to compress the output file
    """
    try:
        # Ensure proper file extension
        if not filename.endswith('.graphml'):
            filename += '.graphml'

        if compress and not filename.endswith('.gz'):
            filename += '.gz'

        # Convert all attributes to strings to ensure compatibility
        G_save = G.copy()

        # Handle node attributes
        for node, attrs in G_save.nodes(data=True):
            for key, value in attrs.items():
                if isinstance(value, (list, dict, set)):
                    G_save.nodes[node][key] = str(value)
                elif pd.isna(value):
                    G_save.nodes[node][key] = ''

        # Handle edge attributes
        for u, v, attrs in G_save.edges(data=True):
            for key, value in attrs.items():
                if isinstance(value, (list, dict, set)):
                    G_save[u][v][key] = str(value)
                elif pd.isna(value):
                    G_save[u][v][key] = ''

        # Save the graph
        nx.write_graphml(G_save, filename)

        print(f"Graph successfully saved to {filename}")

        # Print some statistics
        print(f"\nSaved graph statistics:")
        print(f"Nodes: {G_save.number_of_nodes()}")
        print(f"Edges: {G_save.number_of_edges()}")
        print(f"Node attributes: {list(next(iter(G_save.nodes(data=True)))[1].keys())}")
        edge_attrs = list(next(iter(G_save.edges(data=True)))[2].keys()) if G_save.number_of_edges() > 0 else []
        print(f"Edge attributes: {edge_attrs}")

        return True

    except Exception as e:
        print(f"Error saving graph: {str(e)}")
        return False

# %%
save_graph_to_graphml(G_knn, 'morphological_parrot_network.graphml', compress=False)
# Out:
# Graph successfully saved to morphological_parrot_network.graphml
#
# Saved graph statistics:
# Nodes: 401
# Edges: 1405
# Node attributes: ['latitude', 'longitude', 'family', 'scientific_name']
# Edge attributes: ['weight']
# True

# %%
def analyze_connectivity(G):
    # Check if graph is connected
    is_connected = nx.is_connected(G)

    # Get connected components
    components = list(nx.connected_components(G))
    n_components = len(components)

    # Get largest component
    largest_component = max(components, key=len)

    # Calculate size metrics
    total_nodes = G.number_of_nodes()
    largest_component_size = len(largest_component)
    largest_component_ratio = largest_component_size / total_nodes

    # Create subgraph of largest component
    G_largest = G.subgraph(largest_component)

    # Print analysis
    print(f"Graph Connectivity Analysis:")
    print(f"Is connected: {is_connected}")
    print(f"Number of components: {n_components}")
    print(f"Total nodes: {total_nodes}")
    print(f"Total edges: {G.number_of_edges()}")
    print(f"Largest component size: {largest_component_size}")
    print(f"Largest component ratio: {largest_component_ratio:.2%}")

    # Visualize components
    plt.figure(figsize=(15, 10))

    # Position all nodes using spring layout
    pos = nx.spring_layout(G)

    # Draw each component in a different color
    colors = plt.cm.rainbow(np.linspace(0, 1, n_components))
    for idx, component in enumerate(components):
        nx.draw_networkx_nodes(G, pos,
                             nodelist=list(component),
                             node_color=[colors[idx]],
                             node_size=100,
                             alpha=0.7)

    # Draw edges
    nx.draw_networkx_edges(G, pos, alpha=0.2)

    # Add labels for larger components
    component_sizes = [len(c) for c in components]
    for idx, (component, size) in enumerate(zip(components, component_sizes)):
        if size > total_nodes * 0.05:  # Label components with >5% of nodes
            center_x = np.mean([pos[node][0] for node in component])
            center_y = np.mean([pos[node][1] for node in component])
            plt.text(center_x, center_y, f'Component {idx+1}\n({size} nodes)',
                    horizontalalignment='center',
                    verticalalignment='center',
                    bbox=dict(facecolor='white', alpha=0.7))

    plt.title("Connected Components Visualization")
    plt.axis('off')
    plt.show()

    return {
        'is_connected': is_connected,
        'n_components': n_components,

        'largest_component_size': largest_component_size,
        'largest_component_ratio': largest_component_ratio,

    }

# %%
analyze_connectivity(G_knn)
# Out:
# Graph Connectivity Analysis:
# Is connected: True
# Number of components: 1
# Total nodes: 401
# Total edges: 1405
# Largest component size: 401
# Largest component ratio: 100.00%
# {'is_connected': True,
#  'n_components': 1,
#  'largest_component_size': 401,
#  'largest_component_ratio': 1.0}

# %%
def graphml_to_json_custom(graphml_path, json_path):
    """
    Convert GraphML to custom JSON format with separate node and edge lists
    """
    G = nx.read_graphml(graphml_path)

    # Create custom format
    graph_data = {
        'nodes': [],
        'edges': []
    }

    # Add nodes with attributes
    for node, attrs in G.nodes(data=True):
        node_data = {'id': node}
        node_data.update(attrs)
        graph_data['nodes'].append(node_data)

    # Add edges with attributes
    for source, target, attrs in G.edges(data=True):
        edge_data = {
            'source': source,
            'target': target
        }
        edge_data.update(attrs)
        graph_data['edges'].append(edge_data)

    # Save to file
    with open(json_path, 'w') as f:
        json.dump(graph_data, f, indent=2)

    print(f"Nodes: {len(graph_data['nodes'])}")
    print(f"Edges: {len(graph_data['edges'])}")
    return graph_data

# %%
graphml_to_json_custom('morphological_parrot_network.graphml', 'output.json')
# Out:
# Nodes: 401
# Edges: 1405
# {'nodes': [{'id': 'Eos histrio',
#    'latitude': '4.21',
#    'longitude': '126.78',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eos histrio'},
#   {'id': 'Trichoglossus euteles',
#    'latitude': '-8.98',
#    'longitude': '125.22',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus euteles'},
#   {'id': 'Trichoglossus johnstoniae',
#    'latitude': '7.32',
#    'longitude': '124.74',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus johnstoniae'},
#   {'id': 'Vini australis',
#    'latitude': '-14.66',
#    'longitude': '-172.41',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Vini australis'},
#   {'id': 'Charmosyna palmarum',
#    'latitude': '-15.49',
#    'longitude': '167.39',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Charmosyna palmarum'},
#   {'id': 'Prioniturus mada',
#    'latitude': '-3.44',
#    'longitude': '126.54',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus mada'},
#   {'id': 'Agapornis nigrigenis',
#    'latitude': '-16.86',
#    'longitude': '25.5',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Agapornis nigrigenis'},
#   {'id': 'Loriculus galgulus',
#    'latitude': '1.04',
#    'longitude': '108.17',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Loriculus galgulus'},
#   {'id': 'Loriculus catamene',
#    'latitude': '3.56',
#    'longitude': '125.54',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Loriculus catamene'},
#   {'id': 'Nicopsitta calthrapae',
#    'latitude': '6.94',
#    'longitude': '80.73',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Nicopsitta calthrapae'},
#   {'id': 'Anodorhynchus hyacinthinus',
#    'latitude': '-12.28',
#    'longitude': '-52.74',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Anodorhynchus hyacinthinus'},
#   {'id': 'Primolius maracana',
#    'latitude': '-15.24',
#    'longitude': '-48.58',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Primolius maracana'},
#   {'id': 'Psittacara leucophthalmus',
#    'latitude': '-12.19',
#    'longitude': '-58.18',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara leucophthalmus'},
#   {'id': 'Aratinga jandaya',
#    'latitude': '-6.83',
#    'longitude': '-44.26',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Aratinga jandaya'},
#   {'id': 'Pyrrhura cruentata',
#    'latitude': '-18.24',
#    'longitude': '-40.6',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura cruentata'},
#   {'id': 'Pyrrhura frontalis',
#    'latitude': '-22.57',
#    'longitude': '-48.65',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura frontalis'},
#   {'id': 'Pyrrhura hoematotis',
#    'latitude': '10.26',
#    'longitude': '-67.7',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura hoematotis'},
#   {'id': 'Enicognathus ferrugineus',
#    'latitude': '-44.04',
#    'longitude': '-71.96',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Enicognathus ferrugineus'},
#   {'id': 'Pionites melanocephalus',
#    'latitude': '1.31',
#    'longitude': '-64.3',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionites melanocephalus'},
#   {'id': 'Pionus chalcopterus',
#    'latitude': '2.12',
#    'longitude': '-77.46',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionus chalcopterus'},
#   {'id': 'Pionus fuscus',
#    'latitude': '1.03',
#    'longitude': '-55.72',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionus fuscus'},
#   {'id': 'Trichoglossus flavoviridis',
#    'latitude': '-1.83',
#    'longitude': '125.04',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus flavoviridis'},
#   {'id': 'Pionus tumultuosus',
#    'latitude': '-14.24',
#    'longitude': '-70.31',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionus tumultuosus'},
#   {'id': 'Coracopsis nigra',
#    'latitude': '-19.38',
#    'longitude': '46.7',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Coracopsis nigra'},
#   {'id': 'Psittacara rubritorquis',
#    'latitude': '14.3',
#    'longitude': '-87.25',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara rubritorquis'},
#   {'id': 'Aratinga maculata',
#    'latitude': '-1.5',
#    'longitude': '-54.09',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Aratinga maculata'},
#   {'id': 'Eupsittula astec',
#    'latitude': '17.62',
#    'longitude': '-90.24',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eupsittula astec'},
#   {'id': 'Geoffroyus hyacinthinus',
#    'latitude': '-11.65',
#    'longitude': '160.25',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Geoffroyus hyacinthinus'},
#   {'id': 'Pyrrhura lucianii',
#    'latitude': '-3.67',
#    'longitude': '-66',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura lucianii'},
#   {'id': 'Pyrrhura pacifica',
#    'latitude': '0.99',
#    'longitude': '-78.61',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura pacifica'},
#   {'id': 'Diopsittaca nobilis',
#    'latitude': '5.89',
#    'longitude': '-59.66',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Diopsittaca nobilis'},
#   {'id': 'Tanygnathus gramineus',
#    'latitude': '-3.33',
#    'longitude': '126.36',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Tanygnathus gramineus'},
#   {'id': 'Palaeornis eupatria',
#    'latitude': '21.89',
#    'longitude': '87.11',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Palaeornis eupatria'},
#   {'id': 'Trichoglossus weberi',
#    'latitude': '-8.61',
#    'longitude': '121.15',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus weberi'},
#   {'id': 'Lorius garrulus',
#    'latitude': '0.62',
#    'longitude': '127.97',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Lorius garrulus'},
#   {'id': 'Cacatua haematuropygia',
#    'latitude': '10.02',
#    'longitude': '120.81',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua haematuropygia'},
#   {'id': 'Amazona brasiliensis',
#    'latitude': '-25.12',
#    'longitude': '-48.04',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona brasiliensis'},
#   {'id': 'Psittrichas fulgidus',
#    'latitude': '-5.58',
#    'longitude': '142.61',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittrichas fulgidus'},
#   {'id': 'Pyrrhura leucotis',
#    'latitude': '-19.05',
#    'longitude': '-41.54',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura leucotis'},
#   {'id': 'Amazona vinacea',
#    'latitude': '-24.88',
#    'longitude': '-47.86',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona vinacea'},
#   {'id': 'Amazona rhodocorytha',
#    'latitude': '-20.95',
#    'longitude': '-42.36',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona rhodocorytha'},
#   {'id': 'Poicephalus fuscicollis',
#    'latitude': '-9.56',
#    'longitude': '24.33',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Poicephalus fuscicollis'},
#   {'id': 'Nestor notabilis',
#    'latitude': '-43.37',
#    'longitude': '170.31',
#    'family': 'STRIGOPIDAE',
#    'scientific_name': 'Nestor notabilis'},
#   {'id': 'Prioniturus verticalis',
#    'latitude': '5.2',
#    'longitude': '120.06',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus verticalis'},
#   {'id': 'Charmosyna amabilis',
#    'latitude': '-17.4',
#    'longitude': '171.84',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Charmosyna amabilis'},
#   {'id': 'Polytelis swainsonii',
#    'latitude': '-34.97',
#    'longitude': '146.62',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Polytelis swainsonii'},
#   {'id': 'Chalcopsitta duivenbodei',
#    'latitude': '-3.81',
#    'longitude': '142.3',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Chalcopsitta duivenbodei'},
#   {'id': 'Psitteuteles goldiei',
#    'latitude': '-5.95',
#    'longitude': '142.94',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psitteuteles goldiei'},
#   {'id': 'Lorius lory',
#    'latitude': '-5.26',
#    'longitude': '140.9',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Lorius lory'},
#   {'id': 'Cacatua ducorpsii',
#    'latitude': '-7.84',
#    'longitude': '157.95',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua ducorpsii'},
#   {'id': 'Geoffroyus geoffroyi',
#    'latitude': '-5.48',
#    'longitude': '138.95',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Geoffroyus geoffroyi'},
#   {'id': 'Prioniturus platurus',
#    'latitude': '-2.08',
#    'longitude': '121.33',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus platurus'},
#   {'id': 'Agapornis swindernianus',
#    'latitude': '1.27',
#    'longitude': '19.53',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Agapornis swindernianus'},
#   {'id': 'Ara severus',
#    'latitude': '-4.21',
#    'longitude': '-64.83',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ara severus'},
#   {'id': 'Pyrrhura molinae',
#    'latitude': '-17.59',
#    'longitude': '-61.89',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura molinae'},
#   {'id': 'Brotogeris chiriri',
#    'latitude': '-15.83',
#    'longitude': '-52.56',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Brotogeris chiriri'},
#   {'id': 'Touit dilectissimus',
#    'latitude': '3.24',
#    'longitude': '-77.34',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Touit dilectissimus'},
#   {'id': 'Pionopsitta pileata',
#    'latitude': '-25.86',
#    'longitude': '-50.6',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionopsitta pileata'},
#   {'id': 'Lathamus discolor',
#    'latitude': '-42.48',
#    'longitude': '147.61',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Lathamus discolor'},
#   {'id': 'Cyanoramphus malherbi',
#    'latitude': '-42.76',
#    'longitude': '171.92',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Cyanoramphus malherbi'},
#   {'id': 'Neophema chrysogaster',
#    'latitude': '-42.81',
#    'longitude': '145.83',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Neophema chrysogaster'},
#   {'id': 'Coracopsis vasa',
#    'latitude': '-19.53',
#    'longitude': '46.69',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Coracopsis vasa'},
#   {'id': 'Eolophus roseicapilla',
#    'latitude': '-25.5',
#    'longitude': '134.86',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Eolophus roseicapilla'},
#   {'id': 'Agapornis canus',
#    'latitude': '-19.56',
#    'longitude': '46.7',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Agapornis canus'},
#   {'id': 'Eos bornea',
#    'latitude': '-3.4',
#    'longitude': '128.72',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eos bornea'},
#   {'id': 'Cacatua leadbeateri',
#    'latitude': '-27.45',
#    'longitude': '134.93',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua leadbeateri'},
#   {'id': 'Cacatua galerita',
#    'latitude': '-21',
#    'longitude': '142.3',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua galerita'},
#   {'id': 'Cacatua sanguinea',
#    'latitude': '-25.44',
#    'longitude': '136.73',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua sanguinea'},
#   {'id': 'Agapornis roseicollis',
#    'latitude': '-20.62',
#    'longitude': '16.11',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Agapornis roseicollis'},
#   {'id': 'Agapornis personatus',
#    'latitude': '-5.94',
#    'longitude': '35.62',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Agapornis personatus'},
#   {'id': 'Agapornis lilianae',
#    'latitude': '-11.77',
#    'longitude': '32.72',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Agapornis lilianae'},
#   {'id': 'Ara ararauna',
#    'latitude': '-6.59',
#    'longitude': '-60.82',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ara ararauna'},
#   {'id': 'Aratinga nenday',
#    'latitude': '-22.37',
#    'longitude': '-58.48',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Aratinga nenday'},
#   {'id': 'Forpus passerinus',
#    'latitude': '5.77',
#    'longitude': '-61.48',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Forpus passerinus'},
#   {'id': 'Brotogeris versicolurus',
#    'latitude': '-2.43',
#    'longitude': '-60.82',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Brotogeris versicolurus'},
#   {'id': 'Amazona albifrons',
#    'latitude': '17.92',
#    'longitude': '-92.69',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona albifrons'},
#   {'id': 'Amazona ochrocephala',
#    'latitude': '-1.78',
#    'longitude': '-64.37',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona ochrocephala'},
#   {'id': 'Amazona amazonica',
#    'latitude': '-5.01',
#    'longitude': '-58.9',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona amazonica'},
#   {'id': 'Guaruba guarouba',
#    'latitude': '-4.09',
#    'longitude': '-52.53',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Guaruba guarouba'},
#   {'id': 'Cyanoramphus novaezelandiae',
#    'latitude': '-26.76',
#    'longitude': '149.01',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Cyanoramphus novaezelandiae'},
#   {'id': 'Amazona autumnalis',
#    'latitude': '12.93',
#    'longitude': '-84.94',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona autumnalis'},
#   {'id': 'Geoffroyus heteroclitus',
#    'latitude': '-6.46',
#    'longitude': '154.27',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Geoffroyus heteroclitus'},
#   {'id': 'Trichoglossus chlorolepidotus',
#    'latitude': '-24.16',
#    'longitude': '148.07',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus chlorolepidotus'},
#   {'id': 'Vini ultramarina',
#    'latitude': '-8.91',
#    'longitude': '-139.55',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Vini ultramarina'},
#   {'id': 'Nymphicus hollandicus',
#    'latitude': '-25.22',
#    'longitude': '134.6',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Nymphicus hollandicus'},
#   {'id': 'Tanygnathus lucionensis',
#    'latitude': '11.72',
#    'longitude': '122.9',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Tanygnathus lucionensis'},
#   {'id': 'Prosopeia tabuensis',
#    'latitude': '-16.66',
#    'longitude': '158.98',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prosopeia tabuensis'},
#   {'id': 'Melopsittacus undulatus',
#    'latitude': '-25.84',
#    'longitude': '132.9',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Melopsittacus undulatus'},
#   {'id': 'Psittacara acuticaudatus',
#    'latitude': '-17.6',
#    'longitude': '-59.05',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara acuticaudatus'},
#   {'id': 'Psittacara mitratus',
#    'latitude': '-18.28',
#    'longitude': '-67.37',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara mitratus'},
#   {'id': 'Trichoglossus haematodus',
#    'latitude': '-5.75',
#    'longitude': '142.31',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus haematodus'},
#   {'id': 'Platycercus elegans',
#    'latitude': '-32.73',
#    'longitude': '147.25',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Platycercus elegans'},
#   {'id': 'Pyrrhura griseipectus',
#    'latitude': '-4.28',
#    'longitude': '-38.91',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura griseipectus'},
#   {'id': 'Myiopsitta monachus',
#    'latitude': '-29.98',
#    'longitude': '-60.62',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Myiopsitta monachus'},
#   {'id': 'Psittacara holochlorus',
#    'latitude': '21.32',
#    'longitude': '-97.21',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara holochlorus'},
#   {'id': 'Cyanoliseus patagonus',
#    'latitude': '-36.96',
#    'longitude': '-66.83',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Cyanoliseus patagonus'},
#   {'id': 'Amazona xantholora',
#    'latitude': '19.72',
#    'longitude': '-89',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona xantholora'},
#   {'id': 'Pionus senilis',
#    'latitude': '16.36',
#    'longitude': '-90.11',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionus senilis'},
#   {'id': 'Pyrilia haematotis',
#    'latitude': '14.68',
#    'longitude': '-87.5',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrilia haematotis'},
#   {'id': 'Brotogeris jugularis',
#    'latitude': '9.32',
#    'longitude': '-75.49',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Brotogeris jugularis'},
#   {'id': 'Bolborhynchus lineola',
#    'latitude': '5.54',
#    'longitude': '-82.15',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Bolborhynchus lineola'},
#   {'id': 'Psittacara finschi',
#    'latitude': '10.97',
#    'longitude': '-84.04',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara finschi'},
#   {'id': 'Pyrrhura hoffmanni',
#    'latitude': '9.24',
#    'longitude': '-83.02',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura hoffmanni'},
#   {'id': 'Eos reticulata',
#    'latitude': '-7.57',
#    'longitude': '131.29',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eos reticulata'},
#   {'id': 'Psittacula caniceps',
#    'latitude': '7.06',
#    'longitude': '93.79',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacula caniceps'},
#   {'id': 'Amazona viridigenalis',
#    'latitude': '22.34',
#    'longitude': '-99.08',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona viridigenalis'},
#   {'id': 'Cyanopsitta spixii',
#    'latitude': '',
#    'longitude': '',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Cyanopsitta spixii'},
#   {'id': 'Alexandrinus eques',
#    'latitude': '-20.41',
#    'longitude': '57.47',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Alexandrinus eques'},
#   {'id': 'Psittacara wagleri',
#    'latitude': '5.47',
#    'longitude': '-74.31',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara wagleri'},
#   {'id': 'Anodorhynchus glaucus',
#    'latitude': '',
#    'longitude': '',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Anodorhynchus glaucus'},
#   {'id': 'Psittacus erithacus',
#    'latitude': '0.03',
#    'longitude': '18.71',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacus erithacus'},
#   {'id': 'Amazona aestiva',
#    'latitude': '-17.01',
#    'longitude': '-52.1',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona aestiva'},
#   {'id': 'Pyrrhura melanura',
#    'latitude': '-1.04',
#    'longitude': '-70.48',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura melanura'},
#   {'id': 'Eclectus polychloros',
#    'latitude': '-5.51',
#    'longitude': '141.96',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eclectus polychloros'},
#   {'id': 'Eclectus riedeli',
#    'latitude': '-7.56',
#    'longitude': '131.44',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eclectus riedeli'},
#   {'id': 'Eclectus cornelia',
#    'latitude': '-9.76',
#    'longitude': '119.96',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eclectus cornelia'},
#   {'id': 'Poicephalus senegalus',
#    'latitude': '11.06',
#    'longitude': '-0.67',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Poicephalus senegalus'},
#   {'id': 'Pyrrhura chapmani',
#    'latitude': '2.34',
#    'longitude': '-75.73',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura chapmani'},
#   {'id': 'Eclectus roratus',
#    'latitude': '-1.39',
#    'longitude': '128.26',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eclectus roratus'},
#   {'id': 'Eos semilarvata',
#    'latitude': '-3.14',
#    'longitude': '129.41',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eos semilarvata'},
#   {'id': 'Loriculus flosculus',
#    'latitude': '-8.62',
#    'longitude': '121.11',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Loriculus flosculus'},
#   {'id': 'Charmosyna diadema',
#    'latitude': '',
#    'longitude': '',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Charmosyna diadema'},
#   {'id': 'Eupsittula pertinax',
#    'latitude': '6.29',
#    'longitude': '-66.15',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eupsittula pertinax'},
#   {'id': 'Ara chloropterus',
#    'latitude': '-5.12',
#    'longitude': '-61.95',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ara chloropterus'},
#   {'id': 'Ara macao',
#    'latitude': '-2.86',
#    'longitude': '-63.9',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ara macao'},
#   {'id': 'Forpus conspicillatus',
#    'latitude': '6.3',
#    'longitude': '-73.8',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Forpus conspicillatus'},
#   {'id': 'Pionus menstruus',
#    'latitude': '-4.26',
#    'longitude': '-62.5',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionus menstruus'},
#   {'id': 'Pyrrhura picta',
#    'latitude': '3.06',
#    'longitude': '-58.87',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura picta'},
#   {'id': 'Pyrrhura emma',
#    'latitude': '10.33',
#    'longitude': '-66.31',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura emma'},
#   {'id': 'Amazona diadema',
#    'latitude': '-2.84',
#    'longitude': '-60.55',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona diadema'},
#   {'id': 'Forpus xanthops',
#    'latitude': '-7.37',
#    'longitude': '-77.85',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Forpus xanthops'},
#   {'id': 'Psittacus timneh',
#    'latitude': '6.74',
#    'longitude': '-8.72',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacus timneh'},
#   {'id': 'Ara ambiguus',
#    'latitude': '8.44',
#    'longitude': '-79.83',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ara ambiguus'},
#   {'id': 'Pyrrhura viridicata',
#    'latitude': '11.01',
#    'longitude': '-73.76',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura viridicata'},
#   {'id': 'Amazona dufresniana',
#    'latitude': '4.82',
#    'longitude': '-57',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona dufresniana'},
#   {'id': 'Leptosittaca branickii',
#    'latitude': '-4.59',
#    'longitude': '-75.13',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Leptosittaca branickii'},
#   {'id': 'Trichoglossus forsteni',
#    'latitude': '-8.55',
#    'longitude': '117',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus forsteni'},
#   {'id': 'Anodorhynchus leari',
#    'latitude': '-10.08',
#    'longitude': '-39.3',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Anodorhynchus leari'},
#   {'id': 'Pionus reichenowi',
#    'latitude': '-14.48',
#    'longitude': '-38.88',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionus reichenowi'},
#   {'id': 'Poicephalus cryptoxanthus',
#    'latitude': '-15.7',
#    'longitude': '35.89',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Poicephalus cryptoxanthus'},
#   {'id': 'Cacatua alba',
#    'latitude': '0.69',
#    'longitude': '127.94',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua alba'},
#   {'id': 'Cacatua goffiniana',
#    'latitude': '-7.61',
#    'longitude': '131.37',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua goffiniana'},
#   {'id': 'Cacatua sulphurea',
#    'latitude': '-4.29',
#    'longitude': '121.36',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua sulphurea'},
#   {'id': 'Agapornis fischeri',
#    'latitude': '-3.02',
#    'longitude': '34.28',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Agapornis fischeri'},
#   {'id': 'Amazona collaria',
#    'latitude': '18.18',
#    'longitude': '-77.29',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona collaria'},
#   {'id': 'Amazona leucocephala',
#    'latitude': '21.67',
#    'longitude': '-78.72',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona leucocephala'},
#   {'id': 'Amazona ventralis',
#    'latitude': '18.66',
#    'longitude': '-70.93',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona ventralis'},
#   {'id': 'Amazona vittata',
#    'latitude': '18.29',
#    'longitude': '-65.93',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona vittata'},
#   {'id': 'Coracopsis barklyi',
#    'latitude': '-4.32',
#    'longitude': '55.73',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Coracopsis barklyi'},
#   {'id': 'Amazona finschi',
#    'latitude': '22.34',
#    'longitude': '-104.94',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona finschi'},
#   {'id': 'Amazona versicolor',
#    'latitude': '13.88',
#    'longitude': '-60.97',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona versicolor'},
#   {'id': 'Amazona oratrix',
#    'latitude': '18.34',
#    'longitude': '-93.37',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona oratrix'},
#   {'id': 'Amazona guatemalae',
#    'latitude': '15.79',
#    'longitude': '-88.87',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona guatemalae'},
#   {'id': 'Amazona guildingii',
#    'latitude': '13.25',
#    'longitude': '-61.2',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona guildingii'},
#   {'id': 'Forpus cyanopygius',
#    'latitude': '23.65',
#    'longitude': '-106.42',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Forpus cyanopygius'},
#   {'id': 'Pyrrhura eisenmanni',
#    'latitude': '7.35',
#    'longitude': '-80.7',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura eisenmanni'},
#   {'id': 'Rhynchopsitta terrisi',
#    'latitude': '25.37',
#    'longitude': '-100.42',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Rhynchopsitta terrisi'},
#   {'id': 'Eupsittula nana',
#    'latitude': '18.16',
#    'longitude': '-77.31',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eupsittula nana'},
#   {'id': 'Poicephalus robustus',
#    'latitude': '-30.97',
#    'longitude': '28.7',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Poicephalus robustus'},
#   {'id': 'Ara militaris',
#    'latitude': '-3.31',
#    'longitude': '-74.31',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ara militaris'},
#   {'id': 'Psittacara chloropterus',
#    'latitude': '18.6',
#    'longitude': '-71.47',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara chloropterus'},
#   {'id': 'Amazona arausiaca',
#    'latitude': '15.46',
#    'longitude': '-61.38',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona arausiaca'},
#   {'id': 'Amazona imperialis',
#    'latitude': '15.47',
#    'longitude': '-61.38',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona imperialis'},
#   {'id': 'Pyrrhura subandina',
#    'latitude': '',
#    'longitude': '',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura subandina'},
#   {'id': 'Pyrrhura caeruleiceps',
#    'latitude': '9.51',
#    'longitude': '-73.04',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura caeruleiceps'},
#   {'id': 'Pyrrhura calliptera',
#    'latitude': '4.69',
#    'longitude': '-73.68',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura calliptera'},
#   {'id': 'Psittacara euops',
#    'latitude': '21.49',
#    'longitude': '-78.49',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara euops'},
#   {'id': 'Amazona auropalliata',
#    'latitude': '13.61',
#    'longitude': '-87.61',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona auropalliata'},
#   {'id': 'Pyrrhura rupicola',
#    'latitude': '-11.14',
#    'longitude': '-70.11',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura rupicola'},
#   {'id': 'Nannopsittaca dachilleae',
#    'latitude': '-12.34',
#    'longitude': '-69.75',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Nannopsittaca dachilleae'},
#   {'id': 'Amazona agilis',
#    'latitude': '18.24',
#    'longitude': '-77.54',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona agilis'},
#   {'id': 'Ognorhynchus icterotis',
#    'latitude': '5.24',
#    'longitude': '-75.86',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ognorhynchus icterotis'},
#   {'id': 'Amazona lilacina',
#    'latitude': '-1.91',
#    'longitude': '-79.93',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona lilacina'},
#   {'id': 'Pyrrhura orcesi',
#    'latitude': '-3.26',
#    'longitude': '-79.58',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura orcesi'},
#   {'id': 'Tanygnathus sumatranus',
#    'latitude': '5.59',
#    'longitude': '122.27',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Tanygnathus sumatranus'},
#   {'id': 'Tanygnathus everetti',
#    'latitude': '',
#    'longitude': '',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Tanygnathus everetti'},
#   {'id': 'Eupsittula canicularis',
#    'latitude': '17.22',
#    'longitude': '-96.73',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eupsittula canicularis'},
#   {'id': 'Amazona bodini',
#    'latitude': '7.62',
#    'longitude': '-64.2',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona bodini'},
#   {'id': 'Rhynchopsitta pachyrhyncha',
#    'latitude': '26.45',
#    'longitude': '-106.96',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Rhynchopsitta pachyrhyncha'},
#   {'id': 'Eunymphicus uvaeensis',
#    'latitude': '-20.57',
#    'longitude': '166.57',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eunymphicus uvaeensis'},
#   {'id': 'Loriculus exilis',
#    'latitude': '-1.63',
#    'longitude': '121.35',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Loriculus exilis'},
#   {'id': 'Bolborhynchus ferrugineifrons',
#    'latitude': '3.06',
#    'longitude': '-76.09',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Bolborhynchus ferrugineifrons'},
#   {'id': 'Touit costaricensis',
#    'latitude': '9.55',
#    'longitude': '-83.37',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Touit costaricensis'},
#   {'id': 'Touit stictopterus',
#    'latitude': '-3.34',
#    'longitude': '-78.33',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Touit stictopterus'},
#   {'id': 'Brotogeris pyrrhoptera',
#    'latitude': '-3.2',
#    'longitude': '-79.9',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Brotogeris pyrrhoptera'},
#   {'id': 'Pyrilia pyrilia',
#    'latitude': '7.59',
#    'longitude': '-74.11',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrilia pyrilia'},
#   {'id': 'Hapalopsittaca amazonina',
#    'latitude': '4.83',
#    'longitude': '-74.05',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Hapalopsittaca amazonina'},
#   {'id': 'Hapalopsittaca fuertesi',
#    'latitude': '4.48',
#    'longitude': '-75.55',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Hapalopsittaca fuertesi'},
#   {'id': 'Pyrrhura albipectus',
#    'latitude': '-3.98',
#    'longitude': '-78.72',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura albipectus'},
#   {'id': 'Psittacara erythrogenys',
#    'latitude': '-2.95',
#    'longitude': '-80',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara erythrogenys'},
#   {'id': 'Psittacara frontatus',
#    'latitude': '-10.49',
#    'longitude': '-76.29',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacara frontatus'},
#   {'id': 'Ara rubrogenys',
#    'latitude': '-18.35',
#    'longitude': '-64.86',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ara rubrogenys'},
#   {'id': 'Ara glaucogularis',
#    'latitude': '-14.28',
#    'longitude': '-65.21',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Ara glaucogularis'},
#   {'id': 'Primolius couloni',
#    'latitude': '-10.73',
#    'longitude': '-71.26',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Primolius couloni'},
#   {'id': 'Amazona barbadensis',
#    'latitude': '11.17',
#    'longitude': '-67.94',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona barbadensis'},
#   {'id': 'Pyrrhura pfrimeri',
#    'latitude': '-13.49',
#    'longitude': '-46.66',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura pfrimeri'},
#   {'id': 'Vini peruviana',
#    'latitude': '-15.3',
#    'longitude': '-148.17',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Vini peruviana'},
#   {'id': 'Lorius chlorocercus',
#    'latitude': '-9.75',
#    'longitude': '160.84',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Lorius chlorocercus'},
#   {'id': 'Loriculus pusillus',
#    'latitude': '-7.44',
#    'longitude': '109.66',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Loriculus pusillus'},
#   {'id': 'Enicognathus leptorhynchus',
#    'latitude': '-38.92',
#    'longitude': '-72.64',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Enicognathus leptorhynchus'},
#   {'id': 'Myiopsitta luchsi',
#    'latitude': '-17.51',
#    'longitude': '-65.94',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Myiopsitta luchsi'},
#   {'id': 'Aratinga auricapillus',
#    'latitude': '-17.83',
#    'longitude': '-43.47',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Aratinga auricapillus'},
#   {'id': 'Pyrrhura perlata',
#    'latitude': '-9.85',
#    'longitude': '-58.91',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura perlata'},
#   {'id': 'Pyrrhura devillei',
#    'latitude': '-20.57',
#    'longitude': '-57.03',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura devillei'},
#   {'id': 'Alipiopsitta xanthops',
#    'latitude': '-14.14',
#    'longitude': '-49.2',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Alipiopsitta xanthops'},
#   {'id': 'Triclaria malachitacea',
#    'latitude': '-27.08',
#    'longitude': '-49.68',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Triclaria malachitacea'},
#   {'id': 'Touit huetii',
#    'latitude': '-4.77',
#    'longitude': '-61.57',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Touit huetii'},
#   {'id': 'Pyrrhura snethlageae',
#    'latitude': '-9.68',
#    'longitude': '-61.49',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura snethlageae'},
#   {'id': 'Vini kuhlii',
#    'latitude': '-20.59',
#    'longitude': '-156.92',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Vini kuhlii'},
#   {'id': 'Pionites leucogaster',
#    'latitude': '-7.59',
#    'longitude': '-54.91',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionites leucogaster'},
#   {'id': 'Touit melanonotus',
#    'latitude': '-22.92',
#    'longitude': '-44.66',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Touit melanonotus'},
#   {'id': 'Pyrilia barrabandi',
#    'latitude': '-4.55',
#    'longitude': '-67.41',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrilia barrabandi'},
#   {'id': 'Pyrilia caica',
#    'latitude': '2.63',
#    'longitude': '-57.6',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrilia caica'},
#   {'id': 'Pyrilia aurantiocephala',
#    'latitude': '-6.51',
#    'longitude': '-56.33',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrilia aurantiocephala'},
#   {'id': 'Pyrilia vulturina',
#    'latitude': '-4.9',
#    'longitude': '-53.27',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrilia vulturina'},
#   {'id': 'Amazona festiva',
#    'latitude': '-2.62',
#    'longitude': '-62.48',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona festiva'},
#   {'id': 'Amazona tucumana',
#    'latitude': '-23',
#    'longitude': '-64.39',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona tucumana'},
#   {'id': 'Amazona pretrei',
#    'latitude': '-28.85',
#    'longitude': '-52.03',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona pretrei'},
#   {'id': 'Amazona farinosa',
#    'latitude': '-3.6',
#    'longitude': '-63.4',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona farinosa'},
#   {'id': 'Amazona kawalli',
#    'latitude': '-6.04',
#    'longitude': '-61.12',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Amazona kawalli'},
#   {'id': 'Pionites xanthurus',
#    'latitude': '-6.17',
#    'longitude': '-64.75',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pionites xanthurus'},
#   {'id': 'Trichoglossus rosenbergii',
#    'latitude': '-0.94',
#    'longitude': '135.89',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus rosenbergii'},
#   {'id': 'Pyrrhura lepida',
#    'latitude': '-3.9',
#    'longitude': '-48.94',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura lepida'},
#   {'id': 'Pyrrhura amazonum',
#    'latitude': '-5.02',
#    'longitude': '-51.67',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pyrrhura amazonum'},
#   {'id': 'Eos cyanogenia',
#    'latitude': '-0.97',
#    'longitude': '135.76',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eos cyanogenia'},
#   {'id': 'Zanda baudinii',
#    'latitude': '-34.17',
#    'longitude': '116.7',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Zanda baudinii'},
#   {'id': 'Callocephalon fimbriatum',
#    'latitude': '-35.75',
#    'longitude': '147.35',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Callocephalon fimbriatum'},
#   {'id': 'Micropsitta geelvinkiana',
#    'latitude': '-0.93',
#    'longitude': '135.76',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Micropsitta geelvinkiana'},
#   {'id': 'Neophema chrysostoma',
#    'latitude': '-39.43',
#    'longitude': '145.17',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Neophema chrysostoma'},
#   {'id': 'Cyclopsitta coxeni',
#    'latitude': '-26.37',
#    'longitude': '152.13',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Cyclopsitta coxeni'},
#   {'id': 'Coracopsis sibilans',
#    'latitude': '-11.87',
#    'longitude': '43.63',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Coracopsis sibilans'},
#   {'id': 'Calyptorhynchus lathami',
#    'latitude': '-29.86',
#    'longitude': '149.61',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Calyptorhynchus lathami'},
#   {'id': 'Pezoporus occidentalis',
#    'latitude': '-22.51',
#    'longitude': '127.67',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pezoporus occidentalis'},
#   {'id': 'Psephotellus chrysopterygius',
#    'latitude': '-15.62',
#    'longitude': '143.47',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psephotellus chrysopterygius'},
#   {'id': 'Vini stepheni',
#    'latitude': '-24.36',
#    'longitude': '-128.32',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Vini stepheni'},
#   {'id': 'Zanda latirostris',
#    'latitude': '-32.28',
#    'longitude': '118.12',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Zanda latirostris'},
#   {'id': 'Polytelis alexandrae',
#    'latitude': '-24.39',
#    'longitude': '129.47',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Polytelis alexandrae'},
#   {'id': 'Cyanoramphus unicolor',
#    'latitude': '-49.69',
#    'longitude': '178.8',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Cyanoramphus unicolor'},
#   {'id': 'Cyanoramphus forbesi',
#    'latitude': '-44.27',
#    'longitude': '-176.3',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Cyanoramphus forbesi'},
#   {'id': 'Cyanoramphus auriceps',
#    'latitude': '-43.04',
#    'longitude': '170.77',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Cyanoramphus auriceps'},
#   {'id': 'Nestor meridionalis',
#    'latitude': '-41.88',
#    'longitude': '172.02',
#    'family': 'STRIGOPIDAE',
#    'scientific_name': 'Nestor meridionalis'},
#   {'id': 'Loriculus tener',
#    'latitude': '-5.16',
#    'longitude': '150.99',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Loriculus tener'},
#   {'id': 'Cacatua ophthalmica',
#    'latitude': '-5.47',
#    'longitude': '150.65',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua ophthalmica'},
#   {'id': 'Trichoglossus rubiginosus',
#    'latitude': '6.88',
#    'longitude': '158.22',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus rubiginosus'},
#   {'id': 'Pezoporus wallicus',
#    'latitude': '-36.15',
#    'longitude': '146.08',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Pezoporus wallicus'},
#   {'id': 'Touit surdus',
#    'latitude': '-16.07',
#    'longitude': '-40.97',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Touit surdus'},
#   {'id': 'Probosciger aterrimus',
#    'latitude': '-5.71',
#    'longitude': '140.95',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Probosciger aterrimus'},
#   {'id': 'Psittinus abbotti',
#    'latitude': '2.63',
#    'longitude': '96.07',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittinus abbotti'},
#   {'id': 'Psittinus cyanurus',
#    'latitude': '1.09',
#    'longitude': '108.22',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittinus cyanurus'},
#   {'id': 'Prioniturus flavicans',
#    'latitude': '0.78',
#    'longitude': '123.41',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus flavicans'},
#   {'id': 'Charmosyna margarethae',
#    'latitude': '-8.16',
#    'longitude': '158.57',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Charmosyna margarethae'},
#   {'id': 'Charmosyna meeki',
#    'latitude': '-7.33',
#    'longitude': '157.35',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Charmosyna meeki'},
#   {'id': 'Prosopeia personata',
#    'latitude': '-17.83',
#    'longitude': '177.97',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prosopeia personata'},
#   {'id': 'Prosopeia splendens',
#    'latitude': '-19.03',
#    'longitude': '178.25',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prosopeia splendens'},
#   {'id': 'Charmosyna multistriata',
#    'latitude': '-5.76',
#    'longitude': '140.92',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Charmosyna multistriata'},
#   {'id': 'Hapalopsittaca pyrrhops',
#    'latitude': '-3.17',
#    'longitude': '-78.87',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Hapalopsittaca pyrrhops'},
#   {'id': 'Brotogeris sanctithomae',
#    'latitude': '-6.51',
#    'longitude': '-65.84',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Brotogeris sanctithomae'},
#   {'id': 'Himalayapsitta roseata',
#    'latitude': '18.45',
#    'longitude': '100.6',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Himalayapsitta roseata'},
#   {'id': 'Cacatua moluccensis',
#    'latitude': '-3.22',
#    'longitude': '129.4',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua moluccensis'},
#   {'id': 'Lorius domicella',
#    'latitude': '-3.18',
#    'longitude': '129.22',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Lorius domicella'},
#   {'id': 'Aprosmictus jonquillaceus',
#    'latitude': '-9.16',
#    'longitude': '125.13',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Aprosmictus jonquillaceus'},
#   {'id': 'Eunymphicus cornutus',
#    'latitude': '-21.43',
#    'longitude': '165.66',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eunymphicus cornutus'},
#   {'id': 'Prioniturus mindorensis',
#    'latitude': '12.96',
#    'longitude': '121.07',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus mindorensis'},
#   {'id': 'Zanda funerea',
#    'latitude': '-31.7',
#    'longitude': '147.39',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Zanda funerea'},
#   {'id': 'Calyptorhynchus banksii',
#    'latitude': '-22.18',
#    'longitude': '136.11',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Calyptorhynchus banksii'},
#   {'id': 'Cacatua tenuirostris',
#    'latitude': '-35.63',
#    'longitude': '143.99',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua tenuirostris'},
#   {'id': 'Cacatua pastinator',
#    'latitude': '-30.34',
#    'longitude': '116.67',
#    'family': 'CACATUIDAE',
#    'scientific_name': 'Cacatua pastinator'},
#   {'id': 'Alisterus scapularis',
#    'latitude': '-29.51',
#    'longitude': '149.3',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Alisterus scapularis'},
#   {'id': 'Barnardius zonarius',
#    'latitude': '-27.28',
#    'longitude': '133.19',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Barnardius zonarius'},
#   {'id': 'Glossopsitta concinna',
#    'latitude': '-34.83',
#    'longitude': '146.25',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Glossopsitta concinna'},
#   {'id': 'Glossopsitta porphyrocephala',
#    'latitude': '-33.42',
#    'longitude': '130.5',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Glossopsitta porphyrocephala'},
#   {'id': 'Glossopsitta pusilla',
#    'latitude': '-31.2',
#    'longitude': '148.58',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Glossopsitta pusilla'},
#   {'id': 'Neophema elegans',
#    'latitude': '-31.99',
#    'longitude': '127.74',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Neophema elegans'},
#   {'id': 'Neophema petrophila',
#    'latitude': '-33.43',
#    'longitude': '126.1',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Neophema petrophila'},
#   {'id': 'Neophema pulchella',
#    'latitude': '-32.38',
#    'longitude': '148.84',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Neophema pulchella'},
#   {'id': 'Neophema splendida',
#    'latitude': '-30.2',
#    'longitude': '132.78',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Neophema splendida'},
#   {'id': 'Neopsephotus bourkii',
#    'latitude': '-26.91',
#    'longitude': '129.19',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Neopsephotus bourkii'},
#   {'id': 'Northiella haematogaster',
#    'latitude': '-30.59',
#    'longitude': '141.95',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Northiella haematogaster'},
#   {'id': 'Platycercus adscitus',
#    'latitude': '-23.8',
#    'longitude': '146.69',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Platycercus adscitus'},
#   {'id': 'Platycercus caledonicus',
#    'latitude': '-41.94',
#    'longitude': '146.59',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Platycercus caledonicus'},
#   {'id': 'Platycercus eximius',
#    'latitude': '-33.61',
#    'longitude': '147.21',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Platycercus eximius'},
#   {'id': 'Platycercus icterotis',
#    'latitude': '-32.8',
#    'longitude': '118.49',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Platycercus icterotis'},
#   {'id': 'Platycercus venustus',
#    'latitude': '-15.86',
#    'longitude': '131.32',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Platycercus venustus'},
#   {'id': 'Polytelis anthopeplus',
#    'latitude': '-32.6',
#    'longitude': '124.94',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Polytelis anthopeplus'},
#   {'id': 'Psephotellus dissimilis',
#    'latitude': '-14.54',
#    'longitude': '133.06',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psephotellus dissimilis'},
#   {'id': 'Psephotellus varius',
#    'latitude': '-28.79',
#    'longitude': '131.89',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psephotellus varius'},
#   {'id': 'Psephotus haematonotus',
#    'latitude': '-31.71',
#    'longitude': '145.11',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psephotus haematonotus'},
#   {'id': 'Psitteuteles versicolor',
#    'latitude': '-16.98',
#    'longitude': '135.13',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psitteuteles versicolor'},
#   {'id': 'Purpureicephalus spurius',
#    'latitude': '-33.56',
#    'longitude': '117.94',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Purpureicephalus spurius'},
#   {'id': 'Trichoglossus moluccanus',
#    'latitude': '-26.88',
#    'longitude': '146.33',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus moluccanus'},
#   {'id': 'Trichoglossus rubritorquis',
#    'latitude': '-15.96',
#    'longitude': '130.73',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus rubritorquis'},
#   {'id': 'Prioniturus luconensis',
#    'latitude': '16.24',
#    'longitude': '121.19',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus luconensis'},
#   {'id': 'Prioniturus platenae',
#    'latitude': '9.95',
#    'longitude': '118.71',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus platenae'},
#   {'id': 'Psittacula derbiana',
#    'latitude': '28.04',
#    'longitude': '97.99',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacula derbiana'},
#   {'id': 'Belocercus longicaudus',
#    'latitude': '0.86',
#    'longitude': '110.86',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Belocercus longicaudus'},
#   {'id': 'Prioniturus waterstradti',
#    'latitude': '7.34',
#    'longitude': '125.07',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus waterstradti'},
#   {'id': 'Prioniturus montanus',
#    'latitude': '17.26',
#    'longitude': '121.26',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Prioniturus montanus'},
#   {'id': 'Lorius albidinucha',
#    'latitude': '-4.11',
#    'longitude': '152.69',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Lorius albidinucha'},
#   {'id': 'Psittacula alexandri',
#    'latitude': '19.3',
#    'longitude': '99.68',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psittacula alexandri'},
#   {'id': 'Himalayapsitta finschii',
#    'latitude': '20.39',
#    'longitude': '99.59',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Himalayapsitta finschii'},
#   {'id': 'Trichoglossus iris',
#    'latitude': '-9.13',
#    'longitude': '125.21',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Trichoglossus iris'},
#   {'id': 'Loriculus sclateri',
#    'latitude': '-1.71',
#    'longitude': '124.42',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Loriculus sclateri'},
#   {'id': 'Touit purpuratus',
#    'latitude': '-0.92',
#    'longitude': '-60.92',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Touit purpuratus'},
#   {'id': 'Aprosmictus erythropterus',
#    'latitude': '-21.4',
#    'longitude': '141.37',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Aprosmictus erythropterus'},
#   {'id': 'Eupsittula cactorum',
#    'latitude': '-9.81',
#    'longitude': '-42.06',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eupsittula cactorum'},
#   {'id': 'Eupsittula aurea',
#    'latitude': '-12.63',
#    'longitude': '-50.06',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Eupsittula aurea'},
#   {'id': 'Diopsittaca cumanensis',
#    'latitude': '-12.83',
#    'longitude': '-48.42',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Diopsittaca cumanensis'},
#   {'id': 'Psilopsiagon aurifrons',
#    'latitude': '-20.19',
#    'longitude': '-69.18',
#    'family': 'PSITTACIDAE',
#    'scientific_name': 'Psilopsiagon aurifrons'},
#   {'id': 'Psilopsiagon aymara',
# ...
#    'weight': 0.8566922312898764},
#   {'source': 'Rhynchopsitta terrisi',
#    'target': 'Cacatua tenuirostris',
#    'weight': 0.9286822237379011},
#   {'source': 'Eupsittula nana',
#    'target': 'Psittacara euops',
#    'weight': 0.9317434723137503},
#   {'source': 'Eupsittula nana',
#    'target': 'Aratinga weddellii',
#    'weight': 0.9068800344613873},
#   {'source': 'Eupsittula nana',
#    'target': 'Eupsittula canicularis',
#    'weight': 0.8603287595161688},
#   {'source': 'Poicephalus robustus',
#    'target': 'Poicephalus gulielmi',
#    'weight': 0.9774375102247371},
#   {'source': 'Poicephalus robustus',
#    'target': 'Tanygnathus everetti',
#    'weight': 0.9671175564165551},
#   {'source': 'Poicephalus robustus',
#    'target': 'Tanygnathus sumatranus',
#    'weight': 0.9671175564165551},
#   {'source': 'Poicephalus robustus',
#    'target': 'Tanygnathus megalorynchos',
#    'weight': 0.9383621683924117},
#   {'source': 'Poicephalus robustus',
#    'target': 'Probosciger aterrimus',
#    'weight': 0.9100642958745324},
#   {'source': 'Poicephalus robustus',
#    'target': 'Poicephalus flavifrons',
#    'weight': 0.8542848674725887},
#   {'source': 'Ara militaris',
#    'target': 'Orthopsittaca manilatus',
#    'weight': 0.9475787004439254},
#   {'source': 'Psittacara chloropterus',
#    'target': 'Psittacula alexandri',
#    'weight': 0.8826019127849217},
#   {'source': 'Amazona arausiaca',
#    'target': 'Amazona imperialis',
#    'weight': 0.9832045061734287},
#   {'source': 'Amazona arausiaca',
#    'target': 'Amazona farinosa',
#    'weight': 0.9831016846515745},
#   {'source': 'Amazona arausiaca',
#    'target': 'Cacatua ophthalmica',
#    'weight': 0.9751582958027363},
#   {'source': 'Amazona imperialis',
#    'target': 'Cacatua ophthalmica',
#    'weight': 0.9828100073794994},
#   {'source': 'Amazona imperialis',
#    'target': 'Amazona farinosa',
#    'weight': 0.9680051727134481},
#   {'source': 'Amazona imperialis',
#    'target': 'Nestor meridionalis',
#    'weight': 0.9027461967673684},
#   {'source': 'Amazona imperialis',
#    'target': 'Prosopeia personata',
#    'weight': 0.7856949228022533},
#   {'source': 'Amazona imperialis',
#    'target': 'Prosopeia splendens',
#    'weight': 0.9061941569799071},
#   {'source': 'Pyrrhura subandina',
#    'target': 'Pyrrhura lepida',
#    'weight': 0.993956094210399},
#   {'source': 'Pyrrhura subandina',
#    'target': 'Pyrrhura caeruleiceps',
#    'weight': 0.9814641814152506},
#   {'source': 'Pyrrhura subandina',
#    'target': 'Pyrrhura rupicola',
#    'weight': 0.9801935890918354},
#   {'source': 'Pyrrhura subandina',
#    'target': 'Cyanoramphus auriceps',
#    'weight': 0.9095210198739014},
#   {'source': 'Pyrrhura subandina',
#    'target': 'Brotogeris tirica',
#    'weight': 0.9531803581234679},
#   {'source': 'Pyrrhura subandina',
#    'target': 'Pyrrhura rhodocephala',
#    'weight': 0.9737936968321239},
#   {'source': 'Pyrrhura caeruleiceps',
#    'target': 'Pyrrhura lepida',
#    'weight': 0.9760000793124199},
#   {'source': 'Pyrrhura caeruleiceps',
#    'target': 'Pyrrhura parvifrons',
#    'weight': 0.9730177076323296},
#   {'source': 'Pyrrhura caeruleiceps',
#    'target': 'Cyanoramphus auriceps',
#    'weight': 0.9582658624153767},
#   {'source': 'Pyrrhura caeruleiceps',
#    'target': 'Psephotellus dissimilis',
#    'weight': 0.9467597944705},
#   {'source': 'Pyrrhura calliptera',
#    'target': 'Pyrrhura rhodocephala',
#    'weight': 0.9683609750033738},
#   {'source': 'Pyrrhura calliptera',
#    'target': 'Pyrrhura roseifrons',
#    'weight': 0.9496878088470966},
#   {'source': 'Pyrrhura calliptera',
#    'target': 'Pyrrhura lepida',
#    'weight': 0.9419126232080293},
#   {'source': 'Psittacara euops',
#    'target': 'Eupsittula aurea',
#    'weight': 0.9447247517614243},
#   {'source': 'Psittacara euops',
#    'target': 'Eupsittula canicularis',
#    'weight': 0.9443568811712401},
#   {'source': 'Psittacara euops',
#    'target': 'Aratinga weddellii',
#    'weight': 0.9112565658111041},
#   {'source': 'Amazona auropalliata',
#    'target': 'Amazona farinosa',
#    'weight': 0.9787811971389663},
#   {'source': 'Amazona auropalliata',
#    'target': 'Amazona bodini',
#    'weight': 0.9663125583330816},
#   {'source': 'Amazona auropalliata',
#    'target': 'Deroptyus accipitrinus',
#    'weight': 0.8921234067710656},
#   {'source': 'Pyrrhura rupicola',
#    'target': 'Pyrrhura orcesi',
#    'weight': 0.9889434400824255},
#   {'source': 'Pyrrhura rupicola',
#    'target': 'Pyrrhura albipectus',
#    'weight': 0.9850955810438669},
#   {'source': 'Pyrrhura rupicola',
#    'target': 'Pyrrhura pfrimeri',
#    'weight': 0.9752582263689821},
#   {'source': 'Pyrrhura rupicola',
#    'target': 'Brotogeris tirica',
#    'weight': 0.9601507941625163},
#   {'source': 'Nannopsittaca dachilleae',
#    'target': 'Micropsitta finschii',
#    'weight': 0.9961202530466224},
#   {'source': 'Nannopsittaca dachilleae',
#    'target': 'Micropsitta meeki',
#    'weight': 0.9923737024801511},
#   {'source': 'Nannopsittaca dachilleae',
#    'target': 'Micropsitta keiensis',
#    'weight': 0.9881370357574993},
#   {'source': 'Nannopsittaca dachilleae',
#    'target': 'Forpus spengeli',
#    'weight': 0.9875437933140209},
#   {'source': 'Nannopsittaca dachilleae',
#    'target': 'Cyclopsitta nigrifrons',
#    'weight': 0.9852732305364754},
#   {'source': 'Nannopsittaca dachilleae',
#    'target': 'Hapalopsittaca pyrrhops',
#    'weight': 0.96541706875157},
#   {'source': 'Nannopsittaca dachilleae',
#    'target': 'Hapalopsittaca melanotis',
#    'weight': 0.8742483578485704},
#   {'source': 'Amazona agilis',
#    'target': 'Alipiopsitta xanthops',
#    'weight': 0.9351864015570159},
#   {'source': 'Amazona agilis',
#    'target': 'Pionites xanthomerius',
#    'weight': 0.8963873967852438},
#   {'source': 'Amazona agilis',
#    'target': 'Prioniturus flavicans',
#    'weight': 0.7929884193723881},
#   {'source': 'Ognorhynchus icterotis',
#    'target': 'Tanygnathus megalorynchos',
#    'weight': 0.9718835068934849},
#   {'source': 'Ognorhynchus icterotis',
#    'target': 'Primolius auricollis',
#    'weight': 0.9675613956983793},
#   {'source': 'Ognorhynchus icterotis',
#    'target': 'Rhynchopsitta pachyrhyncha',
#    'weight': 0.9383581412860305},
#   {'source': 'Ognorhynchus icterotis',
#    'target': 'Diopsittaca cumanensis',
#    'weight': 0.9005573492775277},
#   {'source': 'Amazona lilacina',
#    'target': 'Amazona kawalli',
#    'weight': 0.979605658061119},
#   {'source': 'Amazona lilacina',
#    'target': 'Amazona festiva',
#    'weight': 0.9680900745196223},
#   {'source': 'Amazona lilacina',
#    'target': 'Amazona pretrei',
#    'weight': 0.887236694196759},
#   {'source': 'Pyrrhura orcesi',
#    'target': 'Pyrrhura albipectus',
#    'weight': 0.986969033938357},
#   {'source': 'Pyrrhura orcesi',
#    'target': 'Micropsitta finschii',
#    'weight': 0.9720169094789812},
#   {'source': 'Pyrrhura orcesi',
#    'target': 'Micropsitta meeki',
#    'weight': 0.9671065348237023},
#   {'source': 'Pyrrhura orcesi',
#    'target': 'Pyrrhura pfrimeri',
#    'weight': 0.9656759128741091},
#   {'source': 'Tanygnathus sumatranus',
#    'target': 'Tanygnathus everetti',
#    'weight': 1.0},
#   {'source': 'Tanygnathus sumatranus',
#    'target': 'Poicephalus gulielmi',
#    'weight': 0.9520786428002725},
#   {'source': 'Tanygnathus sumatranus',
#    'target': 'Tanygnathus megalorynchos',
#    'weight': 0.9510437531140442},
#   {'source': 'Tanygnathus everetti',
#    'target': 'Poicephalus gulielmi',
#    'weight': 0.9520786428002725},
#   {'source': 'Tanygnathus everetti',
#    'target': 'Tanygnathus megalorynchos',
#    'weight': 0.9510437531140442},
#   {'source': 'Tanygnathus everetti',
#    'target': 'Callocephalon fimbriatum',
#    'weight': 0.8730409013942951},
#   {'source': 'Eupsittula canicularis',
#    'target': 'Eupsittula cactorum',
#    'weight': 0.9568566119345577},
#   {'source': 'Eupsittula canicularis',
#    'target': 'Aratinga weddellii',
#    'weight': 0.9349948250672738},
#   {'source': 'Amazona bodini',
#    'target': 'Amazona festiva',
#    'weight': 0.9890819054787876},
#   {'source': 'Amazona bodini',
#    'target': 'Amazona farinosa',
#    'weight': 0.9811161950946663},
#   {'source': 'Amazona bodini',
#    'target': 'Amazona mercenarius',
#    'weight': 0.9630169295274721},
#   {'source': 'Rhynchopsitta pachyrhyncha',
#    'target': 'Calyptorhynchus lathami',
#    'weight': 0.9644682640022748},
#   {'source': 'Rhynchopsitta pachyrhyncha',
#    'target': 'Zanda baudinii',
#    'weight': 0.9567586915143406},
#   {'source': 'Rhynchopsitta pachyrhyncha',
#    'target': 'Primolius auricollis',
#    'weight': 0.9492750576500203},
#   {'source': 'Rhynchopsitta pachyrhyncha',
#    'target': 'Enicognathus leptorhynchus',
#    'weight': 0.8749772388353579},
#   {'source': 'Eunymphicus uvaeensis',
#    'target': 'Eunymphicus cornutus',
#    'weight': 0.8159729677099538},
#   {'source': 'Eunymphicus uvaeensis',
#    'target': 'Northiella haematogaster',
#    'weight': 0.7497694617676641},
#   {'source': 'Eunymphicus uvaeensis',
#    'target': 'Prosopeia personata',
#    'weight': 0.7413048143599834},
#   {'source': 'Eunymphicus uvaeensis',
#    'target': 'Barnardius zonarius',
#    'weight': 0.7389006794192524},
#   {'source': 'Eunymphicus uvaeensis',
#    'target': 'Cyanoramphus unicolor',
#    'weight': 0.719409410961413},
#   {'source': 'Loriculus exilis',
#    'target': 'Loriculus aurantiifrons',
#    'weight': 0.9982110625505972},
#   {'source': 'Loriculus exilis',
#    'target': 'Micropsitta bruijnii',
#    'weight': 0.9975627007361287},
#   {'source': 'Loriculus exilis',
#    'target': 'Loriculus sclateri',
#    'weight': 0.9941462497835379},
#   {'source': 'Loriculus exilis',
#    'target': 'Loriculus amabilis',
#    'weight': 0.9935838732140826},
#   {'source': 'Loriculus exilis',
#    'target': 'Loriculus tener',
#    'weight': 0.9906924473893765},
#   {'source': 'Bolborhynchus ferrugineifrons',
#    'target': 'Loriculus stigmatus',
#    'weight': 0.9662316092586289},
#   {'source': 'Bolborhynchus ferrugineifrons',
#    'target': 'Loriculus sclateri',
#    'weight': 0.9580243590440407},
#   {'source': 'Bolborhynchus ferrugineifrons',
#    'target': 'Loriculus amabilis',
#    'weight': 0.9575869268264818},
#   {'source': 'Bolborhynchus ferrugineifrons',
#    'target': 'Loriculus tener',
#    'weight': 0.9568889217629181},
#   {'source': 'Bolborhynchus ferrugineifrons',
#    'target': 'Hapalopsittaca fuertesi',
#    'weight': 0.9262302309638237},
#   {'source': 'Bolborhynchus ferrugineifrons',
#    'target': 'Hapalopsittaca pyrrhops',
#    'weight': 0.9488066356957916},
#   {'source': 'Touit costaricensis',
#    'target': 'Touit melanonotus',
#    'weight': 0.9764282195189502},
#   {'source': 'Touit costaricensis',
#    'target': 'Touit stictopterus',
#    'weight': 0.9762906534554479},
#   {'source': 'Touit costaricensis',
#    'target': 'Touit surdus',
#    'weight': 0.9708981531319402},
#   {'source': 'Touit costaricensis',
#    'target': 'Touit huetii',
#    'weight': 0.9691368628892058},
#   {'source': 'Touit costaricensis',
#    'target': 'Prioniturus luconensis',
#    'weight': 0.9449087430910714},
#   {'source': 'Touit stictopterus',
#    'target': 'Touit melanonotus',
#    'weight': 0.9971076071469139},
#   {'source': 'Touit stictopterus',
#    'target': 'Touit surdus',
#    'weight': 0.997072131189986},
#   {'source': 'Touit stictopterus',
#    'target': 'Touit huetii',
#    'weight': 0.995538204888719},
#   {'source': 'Touit stictopterus',
#    'target': 'Brotogeris pyrrhoptera',
#    'weight': 0.9873224964394415},
#   {'source': 'Touit stictopterus',
#    'target': 'Pyrilia pyrilia',
#    'weight': 0.9501096019224129},
#   {'source': 'Touit stictopterus',
#    'target': 'Prioniturus discurus',
#    'weight': 0.9281246092453667},
#   {'source': 'Brotogeris pyrrhoptera',
#    'target': 'Touit melanonotus',
#    'weight': 0.988029637766216},
#   {'source': 'Brotogeris pyrrhoptera',
#    'target': 'Touit huetii',
#    'weight': 0.9863817008697741},
#   {'source': 'Brotogeris pyrrhoptera',
#    'target': 'Touit surdus',
#    'weight': 0.9811801505762697},
#   {'source': 'Brotogeris pyrrhoptera',
#    'target': 'Brotogeris chrysoptera',
#    'weight': 0.9683857608417726},
#   {'source': 'Pyrilia pyrilia',
#    'target': 'Hapalopsittaca amazonina',
#    'weight': 0.9696030163027505},
#   {'source': 'Pyrilia pyrilia',
#    'target': 'Touit melanonotus',
#    'weight': 0.9535916003307958},
#   {'source': 'Pyrilia pyrilia',
#    'target': 'Prioniturus discurus',
#    'weight': 0.9245250625957192},
#   {'source': 'Hapalopsittaca amazonina',
#    'target': 'Loriculus stigmatus',
#    'weight': 0.9554429555373313},
#   {'source': 'Hapalopsittaca amazonina',
#    'target': 'Loriculus sclateri',
#    'weight': 0.9420630785251064},
#   {'source': 'Hapalopsittaca amazonina',
#    'target': 'Prioniturus luconensis',
#    'weight': 0.9378317078357558},
#   {'source': 'Hapalopsittaca amazonina',
#    'target': 'Hapalopsittaca fuertesi',
#    'weight': 0.9168069014188402},
#   {'source': 'Hapalopsittaca amazonina',
#    'target': 'Prioniturus discurus',
#    'weight': 0.9215319262962108},
#   {'source': 'Hapalopsittaca fuertesi',
#    'target': 'Hapalopsittaca pyrrhops',
#    'weight': 0.9351617921052999},
#   {'source': 'Hapalopsittaca fuertesi',
#    'target': 'Hapalopsittaca melanotis',
#    'weight': 0.9122170725741033},
#   {'source': 'Pyrrhura albipectus',
#    'target': 'Pyrrhura pfrimeri',
#    'weight': 0.9579264298349132},
#   {'source': 'Psittacara erythrogenys',
#    'target': 'Primolius auricollis',
#    'weight': 0.8960614282704581},
#   {'source': 'Psittacara frontatus',
#    'target': 'Primolius couloni',
#    'weight': 0.9564301462249464},
#   {'source': 'Psittacara frontatus',
#    'target': 'Diopsittaca cumanensis',
#    'weight': 0.9552240656983847},
#   {'source': 'Psittacara frontatus',
#    'target': 'Psittacula derbiana',
#    'weight': 0.9436718816224298},
#   {'source': 'Ara rubrogenys',
#    'target': 'Ara glaucogularis',
#    'weight': 0.9706501921300199},
#   {'source': 'Ara rubrogenys',
#    'target': 'Primolius couloni',
#    'weight': 0.9627795529274601},
#   {'source': 'Primolius couloni',
#    'target': 'Primolius auricollis',
#    'weight': 0.9632826022389858},
#   {'source': 'Primolius couloni',
#    'target': 'Diopsittaca cumanensis',
#    'weight': 0.9369549357794451},
#   {'source': 'Amazona barbadensis',
#    'target': 'Deroptyus accipitrinus',
#    'weight': 0.9070597887452122},
#   {'source': 'Pyrrhura pfrimeri',
#    'target': 'Brotogeris tirica',
#    'weight': 0.9626755743595358},
#   {'source': 'Vini peruviana',
#    'target': 'Neopsittacus musschenbroekii',
#    'weight': 0.9872669104936},
#   {'source': 'Vini peruviana',
#    'target': 'Neophema pulchella',
#    'weight': 0.9814564139072608},
#   {'source': 'Vini peruviana',
#    'target': 'Neophema splendida',
#    'weight': 0.9777933062918195},
#   {'source': 'Vini peruviana',
#    'target': 'Vini kuhlii',
#    'weight': 0.9694266341196099},
#   {'source': 'Vini peruviana',
#    'target': 'Vini stepheni',
#    'weight': 0.9669991573749048},
#   {'source': 'Lorius chlorocercus',
#    'target': 'Chalcopsitta scintillata',
#    'weight': 0.8164933754804922},
#   {'source': 'Lorius chlorocercus',
#    'target': 'Lorius albidinucha',
#    'weight': 0.7911228293646657},
#   {'source': 'Lorius chlorocercus',
#    'target': 'Eos cyanogenia',
#    'weight': 0.7650098714398331},
#   {'source': 'Loriculus pusillus',
#    'target': 'Loriculus vernalis',
#    'weight': 0.9993257961163721},
#   {'source': 'Loriculus pusillus',
#    'target': 'Loriculus beryllinus',
#    'weight': 0.998231652960514},
#   {'source': 'Loriculus pusillus',
#    'target': 'Trichoglossus meyeri',
#    'weight': 0.9917010350537327},
#   {'source': 'Loriculus pusillus',
#    'target': 'Charmosyna rubronotata',
#    'weight': 0.9897693678847086},
#   {'source': 'Loriculus pusillus',
#    'target': 'Touit purpuratus',
#    'weight': 0.9723737605236871},
#   {'source': 'Enicognathus leptorhynchus',
#    'target': 'Psittacula derbiana',
#    'weight': 0.8955103501247649},
#   {'source': 'Myiopsitta luchsi',
#    'target': 'Himalayapsitta cyanocephala',
#    'weight': 0.9234639641446176},
#   {'source': 'Myiopsitta luchsi',
#    'target': 'Charmosyna josefinae',
#    'weight': 0.8999661732637582},
#   {'source': 'Myiopsitta luchsi',
#    'target': 'Charmosyna stellae',
#    'weight': 0.8563635672425514},
#   {'source': 'Myiopsitta luchsi',
#    'target': 'Nicopsitta columboides',
#    'weight': 0.8395091732803291},
#   {'source': 'Myiopsitta luchsi',
#    'target': 'Himalayapsitta roseata',
#    'weight': 0.8391256898292601},
#   ...]}
