# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from collections import defaultdict

import numpy as np


from scipy.special import factorial
from tqdm import tqdm
from collections import Counter

import math

# %%
def read_graphml(graphml_file):
    try:
        # Read the GraphML file
        G = nx.read_graphml(graphml_file)
        print(f"Graph loaded successfully:")
        print(f"Number of nodes: {G.number_of_nodes()}")
        print(f"Number of edges: {G.number_of_edges()}")
        return G
    except Exception as e:
        print(f"Error reading GraphML file: {str(e)}")
        return None

# %% [markdown]
# A small-world network is a graph characterized by a high clustering coefficient and low distances

# %% [markdown]
# To determine if a network exhibits small-world properties, you typically look for two key characteristics:
#
# **High Clustering Coefficient:** Small-world networks tend to have a significantly higher clustering coefficient than would be expected in a random graph of the same size and average degree.
#
#
# **Short Average Path Length:** Despite the high clustering, small-world networks also have short average path lengths, similar to or even shorter than those in random graphs.

# %%
G_morpho = read_graphml("morphological_parrot_network.graphml")
# Out:
# Graph loaded successfully:
# Number of nodes: 398
# Number of edges: 1372

# %%
def network_metrics(G):
    # Average path length
    try:
        avg_path = nx.average_shortest_path_length(G)
    except nx.NetworkXError:  # handles disconnected graphs
        avg_path = float('inf')

    # Global clustering coefficient (transitivity)
    clustering = nx.transitivity(G)

    print(f"Network Metrics:")
    print("-" * 30)
    print(f"Average Path Length: {avg_path:.3f}")
    print(f"Global Clustering Coefficient: {clustering:.3f}")

    return avg_path, clustering

# %%
network_metrics(G_morpho)
# Out:
# Network Metrics:
# ------------------------------
# Average Path Length: 6.536
# Global Clustering Coefficient: 0.430

# %%
def create_degree_preserved_random(G):
    # Get the degree sequence of original network
    degree_seq = [d for n, d in G.degree()]

    # Create random graph with same degree sequence
    random_G = nx.configuration_model(degree_seq, seed=42)

    # Remove parallel edges and self-loops
    random_G = nx.Graph(random_G)

    return random_G

# %%
G_rand = create_degree_preserved_random(G_morpho)

# %%
network_metrics(G_rand)
# Out:
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016

# %%
def is_small_world(G, n_random=100):
    # Original network metrics
    orig_path, orig_clust = network_metrics(G)

    # Generate random networks and compute average metrics
    random_paths = []
    random_clusts = []

    for i in range(n_random):
        # Create random network preserving degree sequence
        random_G = create_degree_preserved_random(G)

        # Calculate metrics
        rand_path, rand_clust = network_metrics(random_G)
        random_paths.append(rand_path)
        random_clusts.append(rand_clust)

    # Average random metrics
    avg_rand_path = np.mean(random_paths)
    avg_rand_clust = np.mean(random_clusts)

    print("\nSmall-World Analysis:")
    print("-" * 30)
    print(f"Original Network:")
    print(f"  Clustering: {orig_clust:.3f}")
    print(f"  Path Length: {orig_path:.3f}")
    print(f"\nRandom Networks (average over {n_random} networks):")
    print(f"  Clustering: {avg_rand_clust:.3f}")
    print(f"  Path Length: {avg_rand_path:.3f}")

    # Check small-world properties
    is_sw = (orig_clust > avg_rand_clust) and (orig_path <= avg_rand_path * 1.5)

    print(f"\nSmall-world properties: {'Present' if is_sw else 'Absent'}")

    return is_sw

# %%
is_small_world(G_morpho)
# Out:
# Network Metrics:
# ------------------------------
# Average Path Length: 6.536
# Global Clustering Coefficient: 0.430
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
# Network Metrics:
# ------------------------------
# Average Path Length: 3.339
# Global Clustering Coefficient: 0.016
#
# Small-World Analysis:
# ------------------------------
# Original Network:
#   Clustering: 0.430
#   Path Length: 6.536
#
# Random Networks (average over 100 networks):
#   Clustering: 0.016
#   Path Length: 3.339
#
# Small-world properties: Absent
# False

# %%
import networkx as nx
import community.community_louvain as community
import numpy as np

def analyze_community_structure(G):
    # 1. Community Detection using python-louvain's best_partition
    partition = community.best_partition(G)

    # Convert partition dictionary to list of communities
    communities = {}
    for node, comm_id in partition.items():
        if comm_id not in communities:
            communities[comm_id] = []
        communities[comm_id].append(node)
    communities = list(communities.values())

    # 2. Calculate modularity
    modularity = community.modularity(partition, G)

    # 3. Calculate internal and external edges
    internal_edges = 0
    external_edges = 0
    total_edges = G.number_of_edges()

    for comm in communities:
        subgraph = G.subgraph(comm)
        internal_edges += subgraph.number_of_edges()
    external_edges = total_edges - internal_edges

    # 4. Calculate ratios
    internal_density = internal_edges / total_edges
    external_density = external_edges / total_edges

    print("Community Structure Analysis:")
    print("-" * 30)
    print(f"Number of communities: {len(communities)}")
    print(f"Modularity: {modularity:.3f}")
    print("\nEdge Distribution:")
    print(f"Internal edges: {internal_edges} ({internal_density:.1%})")
    print(f"External edges: {external_edges} ({external_density:.1%})")

    # 5. Interpretation
    is_community_based = (
        modularity > 0.3 and
        internal_density > 0.6 and
        len(communities) > 1
    )

    return is_community_based, partition

# To use it:
# result, partition = analyze_community_structure(G)

# %%
analyze_community_structure(G_morpho)
# Out:
# Community Structure Analysis:
# ------------------------------
# Number of communities: 14
# Modularity: 0.804
#
# Edge Distribution:
# Internal edges: 1214 (88.5%)
# External edges: 158 (11.5%)
# (True,
#  {'Eos histrio': 0,
#   'Trichoglossus euteles': 1,
#   'Trichoglossus johnstoniae': 2,
#   'Vini australis': 1,
#   'Charmosyna palmarum': 2,
#   'Prioniturus mada': 3,
#   'Agapornis nigrigenis': 4,
#   'Loriculus galgulus': 5,
#   'Loriculus catamene': 2,
#   'Nicopsitta calthrapae': 6,
#   'Anodorhynchus hyacinthinus': 7,
#   'Primolius maracana': 7,
#   'Psittacara leucophthalmus': 8,
#   'Aratinga jandaya': 0,
#   'Pyrrhura cruentata': 6,
#   'Pyrrhura frontalis': 6,
#   'Pyrrhura hoematotis': 6,
#   'Enicognathus ferrugineus': 0,
#   'Pionites melanocephalus': 9,
#   'Pionus chalcopterus': 9,
#   'Pionus fuscus': 9,
#   'Trichoglossus flavoviridis': 1,
#   'Pionus tumultuosus': 9,
#   'Coracopsis nigra': 10,
#   'Psittacara rubritorquis': 8,
#   'Aratinga maculata': 6,
#   'Eupsittula astec': 6,
#   'Geoffroyus hyacinthinus': 3,
#   'Pyrrhura lucianii': 6,
#   'Pyrrhura pacifica': 6,
#   'Diopsittaca nobilis': 8,
#   'Tanygnathus gramineus': 8,
#   'Palaeornis eupatria': 8,
#   'Trichoglossus weberi': 1,
#   'Lorius garrulus': 11,
#   'Cacatua haematuropygia': 12,
#   'Amazona brasiliensis': 12,
#   'Psittrichas fulgidus': 12,
#   'Pyrrhura leucotis': 6,
#   'Amazona vinacea': 12,
#   'Amazona rhodocorytha': 12,
#   'Poicephalus fuscicollis': 11,
#   'Nestor notabilis': 12,
#   'Charmosyna amabilis': 1,
#   'Polytelis swainsonii': 0,
#   'Chalcopsitta duivenbodei': 12,
#   'Psitteuteles goldiei': 1,
#   'Lorius lory': 11,
#   'Cacatua ducorpsii': 12,
#   'Geoffroyus geoffroyi': 5,
#   'Agapornis swindernianus': 4,
#   'Ara severus': 7,
#   'Pyrrhura molinae': 6,
#   'Brotogeris chiriri': 2,
#   'Touit dilectissimus': 5,
#   'Pionopsitta pileata': 13,
#   'Lathamus discolor': 1,
#   'Cyanoramphus malherbi': 10,
#   'Neophema chrysogaster': 3,
#   'Coracopsis vasa': 8,
#   'Eolophus roseicapilla': 8,
#   'Agapornis canus': 2,
#   'Eos bornea': 8,
#   'Cacatua leadbeateri': 12,
#   'Cacatua galerita': 12,
#   'Cacatua sanguinea': 12,
#   'Agapornis roseicollis': 4,
#   'Agapornis personatus': 4,
#   'Agapornis lilianae': 4,
#   'Ara ararauna': 7,
#   'Aratinga nenday': 0,
#   'Forpus passerinus': 4,
#   'Brotogeris versicolurus': 4,
#   'Amazona albifrons': 9,
#   'Amazona ochrocephala': 12,
#   'Amazona amazonica': 12,
#   'Guaruba guarouba': 11,
#   'Cyanoramphus novaezelandiae': 10,
#   'Amazona autumnalis': 12,
#   'Geoffroyus heteroclitus': 1,
#   'Trichoglossus chlorolepidotus': 1,
#   'Vini ultramarina': 3,
#   'Nymphicus hollandicus': 0,
#   'Tanygnathus lucionensis': 11,
#   'Prosopeia tabuensis': 12,
#   'Melopsittacus undulatus': 1,
#   'Psittacara acuticaudatus': 8,
#   'Psittacara mitratus': 8,
#   'Trichoglossus haematodus': 0,
#   'Platycercus elegans': 10,
#   'Pyrrhura griseipectus': 6,
#   'Myiopsitta monachus': 1,
#   'Psittacara holochlorus': 8,
#   'Cyanoliseus patagonus': 8,
#   'Amazona xantholora': 11,
#   'Pionus senilis': 11,
#   'Pyrilia haematotis': 13,
#   'Brotogeris jugularis': 5,
#   'Bolborhynchus lineola': 1,
#   'Psittacara finschi': 8,
#   'Pyrrhura hoffmanni': 6,
#   'Eos reticulata': 0,
#   'Psittacula caniceps': 10,
#   'Amazona viridigenalis': 12,
#   'Cyanopsitta spixii': 10,
#   'Alexandrinus eques': 10,
#   'Psittacara wagleri': 8,
#   'Anodorhynchus glaucus': 7,
#   'Psittacus erithacus': 11,
#   'Amazona aestiva': 12,
#   'Pyrrhura melanura': 6,
#   'Eclectus polychloros': 12,
#   'Eclectus riedeli': 12,
#   'Eclectus cornelia': 12,
#   'Poicephalus senegalus': 4,
#   'Pyrrhura chapmani': 6,
#   'Eclectus roratus': 12,
#   'Eos semilarvata': 1,
#   'Loriculus flosculus': 5,
#   'Charmosyna diadema': 6,
#   'Eupsittula pertinax': 6,
#   'Ara chloropterus': 7,
#   'Ara macao': 7,
#   'Forpus conspicillatus': 4,
#   'Pionus menstruus': 9,
#   'Pyrrhura picta': 6,
#   'Pyrrhura emma': 6,
#   'Amazona diadema': 12,
#   'Forpus xanthops': 4,
#   'Psittacus timneh': 11,
#   'Ara ambiguus': 7,
#   'Pyrrhura viridicata': 6,
#   'Amazona dufresniana': 12,
#   'Leptosittaca branickii': 10,
#   'Trichoglossus forsteni': 3,
#   'Anodorhynchus leari': 7,
#   'Pionus reichenowi': 9,
#   'Poicephalus cryptoxanthus': 0,
#   'Cacatua alba': 12,
#   'Cacatua goffiniana': 12,
#   'Cacatua sulphurea': 12,
#   'Agapornis fischeri': 4,
#   'Amazona collaria': 12,
#   'Amazona leucocephala': 12,
#   'Amazona ventralis': 12,
#   'Amazona vittata': 12,
#   'Coracopsis barklyi': 10,
#   'Amazona finschi': 12,
#   'Amazona versicolor': 12,
#   'Amazona oratrix': 12,
#   'Amazona guatemalae': 12,
#   'Amazona guildingii': 12,
#   'Forpus cyanopygius': 4,
#   'Pyrrhura eisenmanni': 6,
#   'Rhynchopsitta terrisi': 8,
#   'Eupsittula nana': 6,
#   'Poicephalus robustus': 11,
#   'Ara militaris': 7,
#   'Psittacara chloropterus': 8,
#   'Amazona arausiaca': 12,
#   'Amazona imperialis': 12,
#   'Pyrrhura subandina': 6,
#   'Pyrrhura caeruleiceps': 6,
#   'Pyrrhura calliptera': 6,
#   'Psittacara euops': 6,
#   'Amazona auropalliata': 12,
#   'Pyrrhura rupicola': 6,
#   'Nannopsittaca dachilleae': 13,
#   'Amazona agilis': 9,
#   'Ognorhynchus icterotis': 8,
#   'Amazona lilacina': 12,
#   'Pyrrhura orcesi': 6,
#   'Tanygnathus sumatranus': 11,
#   'Tanygnathus everetti': 11,
#   'Eupsittula canicularis': 6,
#   'Amazona bodini': 12,
#   'Rhynchopsitta pachyrhyncha': 8,
#   'Eunymphicus uvaeensis': 10,
#   'Loriculus exilis': 5,
#   'Bolborhynchus ferrugineifrons': 5,
#   'Touit costaricensis': 5,
#   'Touit stictopterus': 5,
#   'Brotogeris pyrrhoptera': 5,
#   'Pyrilia pyrilia': 5,
#   'Hapalopsittaca amazonina': 5,
#   'Hapalopsittaca fuertesi': 5,
#   'Pyrrhura albipectus': 6,
#   'Psittacara erythrogenys': 8,
#   'Psittacara frontatus': 8,
#   'Ara rubrogenys': 7,
#   'Ara glaucogularis': 7,
#   'Primolius couloni': 8,
#   'Amazona barbadensis': 12,
#   'Pyrrhura pfrimeri': 6,
#   'Vini peruviana': 3,
#   'Lorius chlorocercus': 11,
#   'Loriculus pusillus': 2,
#   'Enicognathus leptorhynchus': 8,
#   'Myiopsitta luchsi': 0,
#   'Aratinga auricapillus': 8,
#   'Pyrrhura perlata': 13,
#   'Pyrrhura devillei': 6,
#   'Alipiopsitta xanthops': 9,
#   'Triclaria malachitacea': 9,
#   'Touit huetii': 5,
#   'Pyrrhura snethlageae': 6,
#   'Vini kuhlii': 3,
#   'Pionites leucogaster': 9,
#   'Touit melanonotus': 5,
#   'Pyrilia barrabandi': 13,
#   'Pyrilia caica': 13,
#   'Pyrilia aurantiocephala': 13,
#   'Pyrilia vulturina': 13,
#   'Amazona festiva': 12,
#   'Amazona tucumana': 12,
#   'Amazona pretrei': 12,
#   'Amazona farinosa': 12,
#   'Amazona kawalli': 12,
#   'Pionites xanthurus': 9,
#   'Trichoglossus rosenbergii': 1,
#   'Pyrrhura lepida': 6,
#   'Pyrrhura amazonum': 6,
#   'Eos cyanogenia': 0,
#   'Zanda baudinii': 8,
#   'Callocephalon fimbriatum': 8,
#   'Micropsitta geelvinkiana': 13,
#   'Neophema chrysostoma': 3,
#   'Cyclopsitta coxeni': 13,
#   'Coracopsis sibilans': 10,
#   'Calyptorhynchus lathami': 8,
#   'Pezoporus occidentalis': 3,
#   'Psephotellus chrysopterygius': 3,
#   'Vini stepheni': 3,
#   'Zanda latirostris': 8,
#   'Polytelis alexandrae': 0,
#   'Cyanoramphus unicolor': 10,
#   'Cyanoramphus forbesi': 13,
#   'Cyanoramphus auriceps': 10,
#   'Nestor meridionalis': 12,
#   'Loriculus tener': 5,
#   'Cacatua ophthalmica': 12,
#   'Trichoglossus rubiginosus': 1,
#   'Pezoporus wallicus': 10,
#   'Touit surdus': 5,
#   'Probosciger aterrimus': 7,
#   'Psittinus abbotti': 1,
#   'Psittinus cyanurus': 1,
#   'Prioniturus flavicans': 9,
#   'Charmosyna margarethae': 2,
#   'Charmosyna meeki': 2,
#   'Prosopeia personata': 12,
#   'Prosopeia splendens': 12,
#   'Charmosyna multistriata': 1,
#   'Hapalopsittaca pyrrhops': 13,
#   'Brotogeris sanctithomae': 4,
#   'Himalayapsitta roseata': 0,
#   'Cacatua moluccensis': 12,
#   'Lorius domicella': 11,
#   'Aprosmictus jonquillaceus': 10,
#   'Eunymphicus cornutus': 10,
#   'Zanda funerea': 8,
#   'Calyptorhynchus banksii': 8,
#   'Cacatua tenuirostris': 11,
#   'Cacatua pastinator': 12,
#   'Alisterus scapularis': 0,
#   'Barnardius zonarius': 10,
#   'Glossopsitta concinna': 1,
#   'Glossopsitta porphyrocephala': 1,
#   'Glossopsitta pusilla': 1,
#   'Neophema elegans': 3,
#   'Neophema petrophila': 3,
#   'Neophema pulchella': 3,
#   'Neophema splendida': 3,
#   'Neopsephotus bourkii': 3,
#   'Northiella haematogaster': 10,
#   'Platycercus adscitus': 3,
#   'Platycercus caledonicus': 10,
#   'Platycercus eximius': 3,
#   'Platycercus icterotis': 3,
#   'Platycercus venustus': 3,
#   'Polytelis anthopeplus': 0,
#   'Psephotellus dissimilis': 3,
#   'Psephotellus varius': 3,
#   'Psephotus haematonotus': 3,
#   'Psitteuteles versicolor': 1,
#   'Purpureicephalus spurius': 10,
#   'Trichoglossus moluccanus': 0,
#   'Trichoglossus rubritorquis': 0,
#   'Prioniturus luconensis': 5,
#   'Prioniturus platenae': 0,
#   'Psittacula derbiana': 8,
#   'Belocercus longicaudus': 0,
#   'Prioniturus waterstradti': 1,
#   'Prioniturus montanus': 3,
#   'Lorius albidinucha': 11,
#   'Psittacula alexandri': 8,
#   'Himalayapsitta finschii': 0,
#   'Trichoglossus iris': 2,
#   'Loriculus sclateri': 5,
#   'Touit purpuratus': 2,
#   'Aprosmictus erythropterus': 0,
#   'Eupsittula cactorum': 6,
#   'Eupsittula aurea': 1,
#   'Diopsittaca cumanensis': 8,
#   'Psilopsiagon aurifrons': 2,
#   'Psilopsiagon aymara': 6,
#   'Chalcopsitta atra': 11,
#   'Primolius auricollis': 8,
#   'Pseudeos fuscata': 0,
#   'Orthopsittaca manilatus': 8,
#   'Pionus maximiliani': 12,
#   'Loriculus beryllinus': 2,
#   'Loriculus philippensis': 5,
#   'Pionites xanthomerius': 9,
#   'Trichoglossus capistratus': 0,
#   'Poicephalus rufiventris': 9,
#   'Poicephalus meyeri': 4,
#   'Psittacella lorentzi': 13,
#   'Psittacella picta': 13,
#   'Touit batavicus': 1,
#   'Nannopsittaca panychlora': 2,
#   'Brotogeris chrysoptera': 4,
#   'Pyrrhura roseifrons': 6,
#   'Tanygnathus megalorynchos': 11,
#   'Loriculus amabilis': 5,
#   'Psittacella brehmii': 13,
#   'Forpus coelestis': 13,
#   'Forpus modestus': 4,
#   'Bolbopsittacus lunulatus': 4,
#   'Psittaculirostris salvadorii': 4,
#   'Pyrrhura parvifrons': 6,
#   'Psittaculirostris edwardsii': 4,
#   'Brotogeris cyanoptera': 13,
#   'Geoffroyus simplex': 0,
#   'Psittacella madaraszi': 13,
#   'Brotogeris tirica': 6,
#   'Psittacella modesta': 13,
#   'Graydidascalus brachyurus': 9,
#   'Hapalopsittaca melanotis': 13,
#   'Alisterus amboinensis': 10,
#   'Pyrilia pulchra': 13,
#   'Alisterus chloropterus': 10,
#   'Oreopsittacus arfaki': 2,
#   'Neopsittacus pullicauda': 3,
#   'Neopsittacus musschenbroekii': 3,
#   'Aratinga weddellii': 6,
#   'Charmosyna rubrigularis': 2,
#   'Psittaculirostris cervicalis': 4,
#   'Psittaculirostris godmani': 4,
#   'Forpus spengeli': 13,
#   'Charmosyna josefinae': 0,
#   'Charmosyna pulchella': 1,
#   'Charmosyna rubronotata': 2,
#   'Forpus xanthopterygius': 13,
#   'Charmosyna placentis': 2,
#   'Charmosyna wilhelminae': 2,
#   'Prioniturus discurus': 5,
#   'Micropsitta meeki': 13,
#   'Micropsitta pusio': 4,
#   'Pyrrhura rhodocephala': 6,
#   'Micropsitta keiensis': 4,
#   'Bolborhynchus orbygnesius': 2,
#   'Micropsitta finschii': 13,
#   'Micropsitta bruijnii': 5,
#   'Pyrrhura peruviana': 6,
#   'Pyrrhura egregia': 6,
#   'Nicopsitta columboides': 0,
#   'Himalayapsitta cyanocephala': 0,
#   'Eos squamata': 0,
#   'Chalcopsitta cardinalis': 0,
#   'Chalcopsitta scintillata': 11,
#   'Pionus seniloides': 12,
#   'Cyclopsitta amabilis': 13,
#   'Cyclopsitta melanogenia': 13,
#   'Cyclopsitta gulielmitertii': 13,
#   'Charmosyna stellae': 0,
#   'Himalayapsitta himalayana': 0,
#   'Alexandrinus krameri': 0,
#   'Lorius hypoinochrous': 11,
#   'Psittaculirostris desmarestii': 4,
#   'Phigys solitarius': 1,
#   'Trichoglossus ornatus': 1,
#   'Cyclopsitta diophthalma': 4,
#   'Trichoglossus meyeri': 2,
#   'Pionus sordidus': 9,
#   'Loriculus vernalis': 2,
#   'Charmosyna papou': 2,
#   'Loriculus aurantiifrons': 5,
#   'Deroptyus accipitrinus': 12,
#   'Loriculus stigmatus': 5,
#   'Poicephalus flavifrons': 11,
#   'Poicephalus crassus': 11,
#   'Poicephalus gulielmi': 11,
#   'Agapornis pullarius': 4,
#   'Amazona mercenarius': 12,
#   'Agapornis taranta': 4,
#   'Cyclopsitta nigrifrons': 4,
#   'Poicephalus rueppellii': 4})

# %%
analyze_community_structure(G_rand)
# Out:
# Community Structure Analysis:
# ------------------------------
# Number of communities: 11
# Modularity: 0.362
#
# Edge Distribution:
# Internal edges: 637 (46.7%)
# External edges: 728 (53.3%)
# (False,
#  {0: 9,
#   1: 3,
#   2: 10,
#   3: 5,
#   4: 7,
#   5: 4,
#   6: 1,
#   7: 7,
#   8: 7,
#   9: 7,
#   10: 4,
#   11: 1,
#   12: 9,
#   13: 9,
#   14: 10,
#   15: 6,
#   16: 7,
#   17: 10,
#   18: 0,
#   19: 2,
#   20: 5,
#   21: 2,
#   22: 3,
#   23: 2,
#   24: 6,
#   25: 8,
#   26: 9,
#   27: 7,
#   28: 3,
#   29: 5,
#   30: 3,
#   31: 6,
#   32: 3,
#   33: 6,
#   34: 0,
#   35: 3,
#   36: 2,
#   37: 9,
#   38: 3,
#   39: 2,
#   40: 2,
#   41: 8,
#   42: 9,
#   43: 3,
#   44: 1,
#   45: 4,
#   46: 7,
#   47: 5,
#   48: 9,
#   49: 5,
#   50: 7,
#   51: 10,
#   52: 5,
#   53: 5,
#   54: 9,
#   55: 9,
#   56: 1,
#   57: 10,
#   58: 1,
#   59: 7,
#   60: 3,
#   61: 9,
#   62: 7,
#   63: 8,
#   64: 2,
#   65: 0,
#   66: 5,
#   67: 4,
#   68: 8,
#   69: 1,
#   70: 2,
#   71: 7,
#   72: 10,
#   73: 0,
#   74: 3,
#   75: 9,
#   76: 1,
#   77: 7,
#   78: 2,
#   79: 1,
#   80: 9,
#   81: 5,
#   82: 4,
#   83: 4,
#   84: 7,
#   85: 5,
#   86: 2,
#   87: 5,
#   88: 8,
#   89: 9,
#   90: 8,
#   91: 3,
#   92: 8,
#   93: 6,
#   94: 3,
#   95: 2,
#   96: 8,
#   97: 3,
#   98: 9,
#   99: 8,
#   100: 1,
#   101: 3,
#   102: 5,
#   103: 2,
#   104: 1,
#   105: 3,
#   106: 0,
#   107: 2,
#   108: 7,
#   109: 3,
#   110: 3,
#   111: 3,
#   112: 1,
#   113: 9,
#   114: 5,
#   115: 1,
#   116: 0,
#   117: 7,
#   118: 3,
#   119: 10,
#   120: 1,
#   121: 2,
#   122: 4,
#   123: 4,
#   124: 9,
#   125: 4,
#   126: 0,
#   127: 3,
#   128: 10,
#   129: 2,
#   130: 3,
#   131: 4,
#   132: 2,
#   133: 3,
#   134: 1,
#   135: 6,
#   136: 5,
#   137: 9,
#   138: 3,
#   139: 2,
#   140: 3,
#   141: 2,
#   142: 4,
#   143: 3,
#   144: 10,
#   145: 9,
#   146: 3,
#   147: 1,
#   148: 6,
#   149: 3,
#   150: 5,
#   151: 5,
#   152: 1,
#   153: 9,
#   154: 2,
#   155: 7,
#   156: 1,
#   157: 8,
#   158: 1,
#   159: 2,
#   160: 9,
#   161: 9,
#   162: 2,
#   163: 1,
#   164: 6,
#   165: 3,
#   166: 4,
#   167: 6,
#   168: 3,
#   169: 2,
#   170: 2,
#   171: 8,
#   172: 4,
#   173: 9,
#   174: 10,
#   175: 3,
#   176: 3,
#   177: 5,
#   178: 7,
#   179: 0,
#   180: 8,
#   181: 9,
#   182: 1,
#   183: 5,
#   184: 5,
#   185: 5,
#   186: 9,
#   187: 1,
#   188: 9,
#   189: 2,
#   190: 1,
#   191: 10,
#   192: 2,
#   193: 10,
#   194: 2,
#   195: 7,
#   196: 0,
#   197: 4,
#   198: 10,
#   199: 6,
#   200: 7,
#   201: 2,
#   202: 1,
#   203: 8,
#   204: 8,
#   205: 9,
#   206: 8,
#   207: 5,
#   208: 3,
#   209: 4,
#   210: 10,
#   211: 8,
#   212: 2,
#   213: 2,
#   214: 7,
#   215: 3,
#   216: 6,
#   217: 2,
#   218: 5,
#   219: 10,
#   220: 2,
#   221: 5,
#   222: 5,
#   223: 5,
#   224: 6,
#   225: 1,
#   226: 8,
#   227: 2,
#   228: 6,
#   229: 7,
#   230: 2,
#   231: 3,
#   232: 3,
#   233: 6,
#   234: 2,
#   235: 4,
#   236: 0,
#   237: 9,
#   238: 8,
#   239: 3,
#   240: 2,
#   241: 1,
#   242: 5,
#   243: 3,
#   244: 4,
#   245: 1,
#   246: 5,
#   247: 10,
#   248: 3,
#   249: 3,
#   250: 2,
#   251: 2,
#   252: 7,
#   253: 2,
#   254: 9,
#   255: 1,
#   256: 2,
#   257: 8,
#   258: 1,
#   259: 2,
#   260: 10,
#   261: 4,
#   262: 1,
#   263: 2,
#   264: 3,
#   265: 1,
#   266: 5,
#   267: 1,
#   268: 2,
#   269: 9,
#   270: 0,
#   271: 10,
#   272: 2,
#   273: 4,
#   274: 7,
#   275: 9,
#   276: 7,
#   277: 4,
#   278: 3,
#   279: 1,
#   280: 1,
#   281: 1,
#   282: 6,
#   283: 3,
#   284: 1,
#   285: 9,
#   286: 9,
#   287: 9,
#   288: 4,
#   289: 4,
#   290: 2,
#   291: 3,
#   292: 1,
#   293: 2,
#   294: 3,
#   295: 7,
#   296: 10,
#   297: 8,
#   298: 5,
#   299: 5,
#   300: 10,
#   301: 4,
#   302: 10,
#   303: 8,
#   304: 10,
#   305: 8,
#   306: 7,
#   307: 2,
#   308: 8,
#   309: 1,
#   310: 3,
#   311: 9,
#   312: 3,
#   313: 4,
#   314: 9,
#   315: 10,
#   316: 9,
#   317: 3,
#   318: 4,
#   319: 7,
#   320: 9,
#   321: 1,
#   322: 6,
#   323: 9,
#   324: 10,
#   325: 2,
#   326: 3,
#   327: 10,
#   328: 7,
#   329: 6,
#   330: 3,
#   331: 3,
#   332: 0,
#   333: 1,
#   334: 7,
#   335: 7,
#   336: 9,
#   337: 6,
#   338: 1,
#   339: 2,
#   340: 1,
#   341: 1,
#   342: 1,
#   343: 2,
#   344: 9,
#   345: 10,
#   346: 5,
#   347: 6,
#   348: 2,
#   349: 2,
#   350: 1,
#   351: 5,
#   352: 9,
#   353: 9,
#   354: 3,
#   355: 5,
#   356: 2,
#   357: 7,
#   358: 7,
#   359: 1,
#   360: 5,
#   361: 3,
#   362: 4,
#   363: 5,
#   364: 9,
#   365: 2,
#   366: 10,
#   367: 8,
#   368: 5,
#   369: 7,
#   370: 4,
#   371: 4,
#   372: 8,
#   373: 5,
#   374: 5,
#   375: 3,
#   376: 6,
#   377: 9,
#   378: 5,
#   379: 8,
#   380: 2,
#   381: 8,
#   382: 8,
#   383: 5,
#   384: 9,
#   385: 8,
#   386: 3,
#   387: 10,
#   388: 6,
#   389: 3,
#   390: 9,
#   391: 1,
#   392: 4,
#   393: 6,
#   394: 3,
#   395: 2,
#   396: 10,
#   397: 1})
